# %%
import requests
import pandas as pd

# %%
df0 = pd.read_csv("df_city_bikes.csv")
df0
# Out:
#      Unnamed: 0                        Station ID                       Name  \
# 0             0  009ac5a5dfe1e13da61ea613ebd580dd                    Alkmaar
# 1             1  00deaf43155f1d6c57891732c5434185            Amsterdam Noord
# 2             2  04672c55a75fa3cdef4533bd1277ec53                  Hoogeveen
# 3             3  0725be1791baf25a0b247bf340560069  Zoetermeer Driemanspolder
# 4             4  07b969ad47b4381c47b2eaa0a50d3d30         Veenendaal Centrum
# ..          ...                               ...                        ...
# 280         280  fd45aafc62edaa3a2759fc5ae6b83dea              Breda Centrum
# 281         281  fd61144b1ba7d7af027695e286da43eb           Zwolle Hanzeland
# 282         282  fdaf68bb8601c63dd8f165750f5d20dd                     Beilen
# 283         283  fdceea2faa8e8b1c5abef210cebdb7d1              Horst Sevenum
# 284         284  fe44fdb504132575b0c631f8f3ba4d80              Anna Paulowna
#
#       Latitude  Longitude  Free Bikes
# 0    52.637530   4.739850         143
# 1    52.402374   4.931019          13
# 2    52.733090   6.473580          36
# 3    52.049090   4.476630          19
# 4    52.019787   5.549334           7
# ..         ...        ...         ...
# 280  51.595020   4.779437         128
# 281  52.504990   6.091060          21
# 282  52.854626   6.520572          12
# 283  51.427600   6.040800          11
# 284  52.867532   4.811490           9
#
# [285 rows x 6 columns]

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
dfa = []
for _, row in df0.iloc[:150].iterrows():
    url = "https://api.foursquare.com/v3/places/search?query=restaurant%20bar&ll={}%2C{}&limit=50&radius=1000".format(row['Latitude'],row['Longitude'])
    
    headers = {
        "accept": "application/json",
        "Authorization": "key"
    }
    
    response = requests.get(url, headers=headers)
    
    dfa.append(response.json())
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# {'results': [{'fsq_id': '2ba9a88b35fc4bc24233deaa',
#    'categories': [{'id': 18021,
#      'name': 'Gym and Studio',
#      'short_name': 'Gym and Studio',
#      'plural_name': 'Gym and Studios',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 872,
#    'geocodes': {'main': {'latitude': 51.790811, 'longitude': 5.648552},
#     'roof': {'latitude': 51.790811, 'longitude': 5.648552}},
#    'link': '/v3/places/2ba9a88b35fc4bc24233deaa',
#    'location': {'address': 'Daalderstraatje 2',
#     'country': 'NL',
#     'formatted_address': 'Daalderstraatje 2, 5371 NX Ravenstein',
#     'locality': 'Ravenstein',
#     'postcode': '5371 NX',
#     'region': 'Noord-Brabant'},
#    'name': 'Bart Brentjens',
#    'related_places': {}}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 51.79464,
#      'longitude': 5.637462},
#     'radius': 1000}}}}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
dfa[0]['results'][0]
# Out:
# {'fsq_id': '4b633f80f964a520656d2ae3',
#  'categories': [{'id': 13065,
#    'name': 'Restaurant',
#    'short_name': 'Restaurant',
#    'plural_name': 'Restaurants',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#     'suffix': '.png'}}],
#  'chains': [],
#  'closed_bucket': 'VeryLikelyOpen',
#  'distance': 862,
#  'geocodes': {'drop_off': {'latitude': 52.629899, 'longitude': 4.742491},
#   'main': {'latitude': 52.62991, 'longitude': 4.742331},
#   'roof': {'latitude': 52.62991, 'longitude': 4.742331}},
#  'link': '/v3/places/4b633f80f964a520656d2ae3',
#  'location': {'address': 'Ritsevoort 60',
#   'country': 'NL',
#   'formatted_address': 'Ritsevoort 60, 1811 DP Alkmaar',
#   'locality': 'Alkmaar',
#   'postcode': '1811 DP',
#   'region': 'Noord-Holland'},
#  'name': "Abby's Restaurant",
#  'related_places': {},
#  'timezone': 'Europe/Amsterdam'}

# %%
list = []
statNameList = df0['Name'][:150]
nameIndex = -1
for item in dfa:
    nameIndex += 1
    for loca in item['results']:
        sl = []
        sl.append(loca['name'])
        sl.append(loca['distance'])
        sl.append(statNameList[nameIndex])
        list.append(sl)
# Out:
# [["Abby's Restaurant", 862, 'Alkmaar'],
#  ['Restaurant Stoer', 97, 'Alkmaar'],
#  ['King Sing Chinees-Indisch Restaurant', 211, 'Alkmaar'],
#  ["Restaurant 't Stokpaardje", 819, 'Alkmaar'],
#  ['Restaurant Het Gulden Vlies', 749, 'Alkmaar'],
#  ['Restaurant Uma', 565, 'Alkmaar'],
#  ['Cafe - Bar Eiland', 103, 'Alkmaar'],
#  ['Indonesisch Restaurant Deli', 1008, 'Alkmaar'],
#  ['Grieks Restaurant Mylos', 916, 'Alkmaar'],
#  ['Bar Slecht', 621, 'Alkmaar'],
#  ['Restaurant Lindetuin', 632, 'Alkmaar'],
#  ['Kosteluk Restaurant', 306, 'Alkmaar'],
#  ['Victor Bar', 682, 'Alkmaar'],
#  ['Café Food Bar ‘t Steegje', 688, 'Alkmaar'],
#  ['Alkmaarse Restaurant 10-daagse', 698, 'Alkmaar'],
#  ['Restaurant Alkmaer', 927, 'Alkmaar'],
#  ['Brasserie-bar X-press', 747, 'Alkmaar'],
#  ['Super Thai Thais Restaurant', 752, 'Alkmaar'],
#  ['Dynasty Chinees-Indisch Restaurant', 875, 'Alkmaar'],
#  ['Blue District Restaurant', 885, 'Alkmaar'],
#  ['Bar Club Cheeese Alkmaar', 943, 'Alkmaar'],
#  ['Bar Cafe Gewaagd', 964, 'Alkmaar'],
#  ['Cottura lunchroom/restaurant', 967, 'Alkmaar'],
#  ['Thais Restaurant Khunchai', 997, 'Alkmaar'],
#  ['Vito Restaurant', 585, 'Alkmaar'],
#  ['Bar-Restaurant Hofman', 603, 'Alkmaar'],
#  ['Indiaas en Sri Lankaans Restaurant Sumangali', 737, 'Alkmaar'],
#  ['Restaurant Zegels', 749, 'Alkmaar'],
#  ['Grand Café Restaurant Zinin', 934, 'Alkmaar'],
#  ['Sabor Bar Restaurante', 941, 'Alkmaar'],
#  ['Grieks Specialiteiten Restaurant Irodion', 990, 'Alkmaar'],
#  ['Restaurant', 16, 'Amsterdam Noord'],
#  ['BoulesBitesBar', 274, 'Amsterdam Noord'],
#  ['Restaurant De Beren Amsterdam-Noord', 309, 'Amsterdam Noord'],
#  ["Bert's Restaurant, Amsterdam Netherlands", 346, 'Amsterdam Noord'],
#  ['Bakker Bart', 549, 'Amsterdam Noord'],
#  ['David Barberi', 591, 'Amsterdam Noord'],
#  ['Favori Cafe Restaurant', 685, 'Amsterdam Noord'],
#  ['Dar Al Yemen restaurant', 736, 'Amsterdam Noord'],
#  ['Max Grill-Bar The', 387, 'Amsterdam Noord'],
#  ['Hollywood Barbersclub', 797, 'Amsterdam Noord'],
#  ['Nieuwendam Clara Barton Str', 950, 'Amsterdam Noord'],
#  ['Holland & Barrett', 557, 'Amsterdam Noord'],
#  ['Baris Bouw', 651, 'Amsterdam Noord'],
#  ['Baren Design, Van', 741, 'Amsterdam Noord'],
#  ['Osaka Teppanyaki Restaurant', 784, 'Amsterdam Noord'],
#  ['Baryar', 924, 'Amsterdam Noord'],
#  ['Barbara Maakt', 933, 'Amsterdam Noord'],
#  ['Bariosho-Ret', 975, 'Amsterdam Noord'],
#  ['Restaurant Het Station', 566, 'Hoogeveen'],
#  ['Restaurant-Steakhouse Brasil', 843, 'Hoogeveen'],
#  ['Restaurant de Muzikant - Hoogeveen', 843, 'Hoogeveen'],
#  ["d' Olde Kei barbecue restaurant", 496, 'Hoogeveen'],
#  ['Restaurant De Manderijn', 504, 'Hoogeveen'],
#  ['Artistic Barber', 935, 'Hoogeveen'],
#  ["Bar Dancing Kegelbaan D'oale Heerdt", 539, 'Hoogeveen'],
#  ['Ohrid Balkan Specialiteiten Restaurant', 986, 'Hoogeveen'],
#  ["Restaurant J. Van 't Hooge", 714, 'Hoogeveen'],
#  ['Restaurant De Pompoen', 835, 'Hoogeveen'],
#  ["Bogatti's Restaurant", 130, 'Zoetermeer Driemanspolder'],
#  ['Bar Golden Tulip Zoetermeer', 137, 'Zoetermeer Driemanspolder'],
#  ['Restaurant La Copa (NH Hotel)', 332, 'Zoetermeer Driemanspolder'],
#  ['Compact Bar', 539, 'Zoetermeer Driemanspolder'],
#  ['Barretje Van Hans', 560, 'Zoetermeer Driemanspolder'],
#  ['Baran restaurant', 611, 'Zoetermeer Driemanspolder'],
#  ['Indonesisch Restaurant Sari', 657, 'Zoetermeer Driemanspolder'],
#  ['parkeerplaats,Barendrecht,botter', 805, 'Zoetermeer Driemanspolder'],
#  ['Johnny Restaurant & Eetcafé', 832, 'Zoetermeer Driemanspolder'],
#  ['Handelsmaatschappij Barret BV', 518, 'Zoetermeer Driemanspolder'],
#  ['Holland & Barrett', 627, 'Zoetermeer Driemanspolder'],
#  ['Restaurant Il Carpaccio', 682, 'Zoetermeer Driemanspolder'],
#  ['Barendse Transport & Dienstverlening', 805, 'Zoetermeer Driemanspolder'],
#  ['Juridisch Adviesbur Baren Hoefer & Olthof',
#   990,
#   'Zoetermeer Driemanspolder'],
#  ['Restaurant Mucha', 479, 'Veenendaal Centrum'],
#  ['Argentijns Restaurant El Rancho', 525, 'Veenendaal Centrum'],
#  ['Debuut Restaurant Het', 638, 'Veenendaal Centrum'],
#  ["Mango's Cantina y Bar", 658, 'Veenendaal Centrum'],
#  ['Macedonish Restaurant Kantina', 674, 'Veenendaal Centrum'],
#  ['Phoenix Express Restaurant', 683, 'Veenendaal Centrum'],
#  ['Barbone', 318, 'Veenendaal Centrum'],
#  ['Grieks Restaurant Omega', 692, 'Veenendaal Centrum'],
#  ['Grieks Restaurant Attica', 694, 'Veenendaal Centrum'],
#  ['Chinees Spec Restaurant New Eastern City', 694, 'Veenendaal Centrum'],
#  ['Bart Bakkerij', 707, 'Veenendaal Centrum'],
#  ['Kolonie Restaurant Café De', 775, 'Veenendaal Centrum'],
#  ['Restaurant Plantage', 794, 'Veenendaal Centrum'],
#  ['Wok & Live Cooking Restaurant Eastern Plaza', 809, 'Veenendaal Centrum'],
#  ['Petit Restaurant De Buffel', 820, 'Veenendaal Centrum'],
#  ['Cafe Bar En Boos', 617, 'Veenendaal Centrum'],
#  ['Dolce Vita Veenendaal Restaurant', 674, 'Veenendaal Centrum'],
#  ['Bureau Barcode', 686, 'Veenendaal Centrum'],
#  ['Tres Tapas & Wine Bar', 690, 'Veenendaal Centrum'],
#  ['Holland & Barrett', 759, 'Veenendaal Centrum'],
#  ['Dragonder, Bar', 1484, 'Veenendaal Centrum'],
#  ['Grieks Specialiteiten Restaurant Kreta', 397, 'Sneek'],
#  ['Bart Bakkerij', 665, 'Sneek'],
#  ['Restaurant Texas Steak', 348, 'Sneek'],
#  ['Onder de Linden Restaurant', 526, 'Sneek'],
#  ['Hotel Cafe Restaurant Klein Genot', 371, 'Sneek'],
#  ['Barolo Company', 455, 'Sneek'],
#  ['Kastanje Restaurant De', 460, 'Sneek'],
#  ['Kapsalon De Barbier', 474, 'Sneek'],
#  ['Bar Dancing The Legend', 515, 'Sneek'],
#  ['Cafe Restaurant Stadszaal', 527, 'Sneek'],
#  ['M.A.F. Zonneveld t.h.o.d.n. Bakkerij Bart', 668, 'Sneek'],
#  ['Hindelooper Kamer Restaurant Bistro', 683, 'Sneek'],
#  ['Holland & Barrett', 782, 'Sneek'],
#  ["B'art", 805, 'Sneek'],
#  ['Bar La Boheme', 430, 'Sneek'],
#  ["Restaurant-Bar 't Stoofje", 474, 'Sneek'],
#  ['Bar-Dancing Sneeker Pan', 485, 'Sneek'],
#  ['Restaurant Nu', 746, 'Sneek'],
#  ['Jane en Barnie Bedrijfskleding', 695, 'Sneek'],
#  ['Haifa Restaurant', 737, 'Sneek'],
#  ['Ming Tjang Chinees Restaurant', 740, 'Sneek'],
#  ['Restaurant Bernard', 426, 'Voorburg'],
#  ['Grieks Restaurant Kreta', 119, 'Voorburg'],
#  ['Le Barquichon', 357, 'Voorburg'],
#  ['Kompaan Craft Beer Bar', 907, 'Voorburg'],
#  ['Thai Restaurant Bangkok', 163, 'Voorburg'],
#  ['Galazio Restaurant', 186, 'Voorburg'],
#  ['Bar Restaurant The Fox', 489, 'Voorburg'],
#  ['Restaurant 1723', 418, 'Voorburg'],
#  ['Exadas Mediterannean Restaurant', 281, 'Voorburg'],
#  ['Jeffrey Grill-Restaurant', 341, 'Voorburg'],
#  ['Restaurant Strooper De', 357, 'Voorburg'],
#  ['Specialiteiten Restaurant Solmar', 391, 'Voorburg'],
#  ['Restaurant Eigenwijz', 418, 'Voorburg'],
#  ['Bon Bon Restaurant', 418, 'Voorburg'],
#  ['Mövenpick Restaurant Voorburg', 108, 'Voorburg'],
#  ['Restaurant The River', 426, 'Voorburg'],
#  ["Stuut's Petit-Restaurant", 112, 'Voorburg'],
#  ['Bartolomeo', 429, 'Voorburg'],
#  ['Eye Of Bartolino', 476, 'Voorburg'],
#  ['Barretje van Hans', 665, 'Voorburg'],
#  ['Fons Bar', 671, 'Voorburg'],
#  ['Fons Bar Tafelvoetbal', 671, 'Voorburg'],
#  ['KPN Restaurant', 675, 'Voorburg'],
#  ['Brasserie-restaurant Jules', 349, 'Voorburg'],
#  ['Cup Espresso Bar', 751, 'Voorburg'],
#  ['Zenzo Japans Restaurant', 385, 'Voorburg'],
#  ['Koppe Photography & Design Barbara', 406, 'Voorburg'],
#  ['YI Soon Chinees-Indisch Restaurant', 432, 'Voorburg'],
#  ['VaVoom Tiki Bar', 862, 'Voorburg'],
#  ['Sinar Baru', 476, 'Voorburg'],
#  ['Peaky Barber', 941, 'Voorburg'],
#  ["McDonald's Restaurant", 967, 'Voorburg'],
#  ["Henry's Barbershop", 589, 'Voorburg'],
#  ['Restaurant Five', 81, 'Oss'],
#  ["Restaurant D'n Toei", 27, 'Oss'],
#  ['Japans Restaurant Tanuki', 664, 'Oss'],
#  ['Antep Künefe Restaurant', 137, 'Oss'],
#  ['Türkiye Restaurant', 143, 'Oss'],
#  ['Chinees restaurant Lotus', 192, 'Oss'],
#  ['Restaurant Ensar', 467, 'Oss'],
#  ['Inotec Barcode Security BV', 333, 'Oss'],
#  ['Restaurant Pardon', 480, 'Oss'],
#  ['Chinees-Indisch Restaurant Lotus', 81, 'Oss'],
#  ['Oriënt Garden Chinees Speciaal Restaurant', 442, 'Oss'],
#  ['Ziza Egyptisch Restaurant', 453, 'Oss'],
#  ["Restaurant Don Serrano's CV", 464, 'Oss'],
#  ['Restaurant Rossetti', 480, 'Oss'],
#  ['Eetcafe restaurant Sirtaki', 505, 'Oss'],
#  ['Bakkerij Bart Oss Centrum', 521, 'Oss'],
#  ['Grieks Restaurant Olympia', 527, 'Oss'],
#  ['Notaris Barbara van Kampen', 617, 'Oss'],
#  ['Onsz Restaurant Oss', 643, 'Oss'],
#  ['Bar15', 657, 'Oss'],
#  ['Six Feet Under barber/tattoo', 670, 'Oss'],
#  ['Bar & Grill Woodstock', 687, 'Oss'],
#  ["Disco's Barbershop", 703, 'Oss'],
#  ['Sunrise Argentina houtskool grill restaurant', 718, 'Oss'],
#  ['Ye & Lin Chinees Restaurant', 448, 'Oss'],
#  ['Bartufique Kids', 475, 'Oss'],
#  ['Adanos Restaurant', 903, 'Oss'],
#  ['Salsa Teatro Restaurante', 485, 'Oss'],
#  ['Golfbad Café Restaurant De Uitkijk', 927, 'Oss'],
#  ['The Saloon Cafe/Bar', 500, 'Oss'],
#  ['Restaurant Lana', 642, 'Oss'],
#  ['Scvo Barbeque', 932, 'Oss'],
#  ['Restaurant-Brasserie De Houtsnip', 511, 'Oss'],
#  ['Adanos Restaurant', 518, 'Oss'],
#  ['Bakkerij Bart Oss Centrum', 521, 'Oss'],
#  ['Wereldwok Restaurant Oss BV', 971, 'Oss'],
#  ['Bartufique', 547, 'Oss'],
#  ['Holland & Barrett', 599, 'Oss'],
#  ['Heuvell Tot Westerflier Bv, Baron A Van', 619, 'Oss'],
#  ["Restaurant 't Stekkie", 730, 'Oss'],
#  ['Restaurant LEUK', 899, 'Bussum Zuid'],
#  ['Restaurant Soigné', 972, 'Bussum Zuid'],
#  ['Argentijns Grill Restaurant Chaco', 795, 'Bussum Zuid'],
#  ['Bar du Baron', 461, 'Bussum Zuid'],
#  ['Bar 55', 502, 'Bussum Zuid'],
#  ['Restaurant', 947, 'Bussum Zuid'],
#  ['Poke Burrito Restaurant', 657, 'Bussum Zuid'],
#  ['Bardot Lingerie', 903, 'Bussum Zuid'],
#  ['Restaurant Therapy', 946, 'Bussum Zuid'],
#  ['Kevin’s Barber Shop', 965, 'Bussum Zuid'],
#  ['Sweetie Chinees-Surinaams Restaurant', 990, 'Bussum Zuid'],
#  ["Bar 't Brinkie", 783, 'Bussum Zuid'],
#  ['Sakura Restaurant', 931, 'Bussum Zuid'],
#  ['Restaurant Atlantique', 946, 'Bussum Zuid'],
#  ['Riche Hotel Café Restaurant', 902, 'Boxmeer'],
#  ['Hotel Restaurant De Baronie', 239, 'Boxmeer'],
#  ['Restaurant Brasserie De Bock', 733, 'Boxmeer'],
#  ['Restaurant De Proeftuin / Cas spijkers Academy', 350, 'Boxmeer'],
#  ['Palingkwekerij Bardoel', 711, 'Boxmeer'],
#  ['Bakker Bart', 846, 'Boxmeer'],
#  ['Bart Boxmeer Bakker', 851, 'Boxmeer'],
#  ['Hermans Hoefsmederij Bart', 443, 'Boxmeer'],
#  ['Restaurant/Lunchroom Het Kantongerecht', 855, 'Boxmeer'],
#  ['Witte Brug Restaurant Zaal De', 910, 'Boxmeer'],
#  ['New Lotus Chinees-Indisch Restaurant', 938, 'Boxmeer'],
#  ['Kapadokya Turks Restaurant', 866, 'Boxmeer'],
#  ['Restaurant King', 366, 'Didam'],
#  ['Günes Pizzeria Restaurant', 453, 'Didam'],
#  ['launch bar v. Dulmen', 410, 'Didam'],
#  ['Chinees Indonesische Restaurant "Azie"', 789, 'Didam'],
#  ['Kwong Chow Chinees-Indisch Restaurant', 795, 'Didam'],
#  ['Nieuw-Azië Chinees-Indisch Restaurant', 795, 'Didam'],
#  ['Cafe Restaurant Het Zwijnshoofd', 532, 'Didam'],
#  ['Restaurant Boven Groningen', 112, 'Delfzijl'],
#  ['Hotel Restaurant Boven Groningen', 124, 'Delfzijl'],
#  ['Bakker Bart', 221, 'Delfzijl'],
#  ['Grill Restaurant Lale', 383, 'Delfzijl'],
#  ['Restaurant De Kakebrug', 419, 'Delfzijl'],
#  ['Barbèr Haarverzorging', 249, 'Delfzijl'],
#  ["Money's Bar", 256, 'Delfzijl'],
#  ["Dolfie's Bar", 287, 'Delfzijl'],
#  ['Wijnne & Barends Delfzijl', 762, 'Delfzijl'],
#  ["Wijnne & Barends' Cargadoors- en Agentuurkantoren B.V.", 762, 'Delfzijl'],
#  ['Doklanden Cafetaria-Restaurant', 795, 'Delfzijl'],
#  ['Cafetaria Barry', 474, 'Maassluis'],
#  ['Musketier Bar Bodega De', 476, 'Maassluis'],
#  ['Kookminister De Restaurant', 585, 'Maassluis'],
#  ['Camelot Restaurant', 601, 'Maassluis'],
#  ['Grieks Restaurant Alfa', 602, 'Maassluis'],
#  ['Borrel Bar Bites', 617, 'Maassluis'],
#  ['Barendregt Ademhalings & Ontspanningstherapie Maassluis', 621, 'Maassluis'],
#  ['Piramide Steakhouse Pizzeria Multicultureel Restaurant', 659, 'Maassluis'],
#  ['Barbershop Uppercut', 694, 'Maassluis'],
#  ['Restaurant De Beren Maassluis', 704, 'Maassluis'],
#  ['Bart Grond & Waterwerken Karl', 344, 'Maassluis'],
#  ["Kevin's Grand Café & Restaurant", 724, 'Maassluis'],
#  ['EuroZaken Financieringen Barentszzee BV', 731, 'Maassluis'],
#  ['Barbershop Maassluis', 527, 'Maassluis'],
#  ['Bouwbedrijf Barten', 220, 'OV-ebike Driebergen-Zeist'],
#  ['Lunch Restaurant Elsevier', 122, 'Amsterdam Sloterdijk'],
#  ['Pancake restaurant Rozen gracht amsterdam', 130, 'Amsterdam Sloterdijk'],
#  ['Espresso Bar Uwv', 256, 'Amsterdam Sloterdijk'],
#  ['Restaurant', 552, 'Amsterdam Sloterdijk'],
#  ['UWV restaurant C-D', 284, 'Amsterdam Sloterdijk'],
#  ['Urban Lodge Hotel Restaurant', 347, 'Amsterdam Sloterdijk'],
#  ['Restaurantkaart.nl', 406, 'Amsterdam Sloterdijk'],
#  ['TMG Restaurant', 414, 'Amsterdam Sloterdijk'],
#  ['ROC Restaurant', 417, 'Amsterdam Sloterdijk'],
#  ['MTTM Bar', 481, 'Amsterdam Sloterdijk'],
#  ['Q port Veerkampjes Restaurant', 496, 'Amsterdam Sloterdijk'],
#  ['Statema Lounge - MTTM bar', 554, 'Amsterdam Sloterdijk'],
#  ['Café-Bar Ton-Ton', 576, 'Amsterdam Sloterdijk'],
#  ['Bar GoWest', 587, 'Amsterdam Sloterdijk'],
#  ['Atos Amsterdam Company Restaurant', 678, 'Amsterdam Sloterdijk'],
#  ['Lauras&Marthes Bar In Adam', 962, 'Amsterdam Sloterdijk'],
#  ['Azië Chinees-Indisch Restaurant', 460, 'Dieren'],
#  ["Gino's Place Café Restaurant en Pizzeria", 328, 'Dieren'],
#  ['Tijd Restaurant', 633, 'Dieren'],
#  ['Barisoft', 536, 'Dieren'],
#  ['Toko Warung Baru', 575, 'Dieren'],
#  ['Heeren van Leeuw De Restaurant', 528, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Restaurant Syr', 954, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['LE:EN Aziatisch Restaurant', 123, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Monsieur Moustache barber shop', 329, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Nostro Bar', 396, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Restaurant Meneer Buscourr', 896, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Barnsteenlaan 7', 510, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Restaurant De Thai', 935, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Bar Hoograven', 734, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Cafe Restaurant Casablanca', 969, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Grill Restaurant Pelin', 609, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Restaurant Culinair Podium', 830, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Grieks Restaurant Delphi', 453, 'Zoetermeer Centrum West'],
#  ['Jasmijn Chinees-Indisch Restaurant', 86, 'Zoetermeer Centrum West'],
#  ['Zoetermeer Barbershop', 158, 'Zoetermeer Centrum West'],
#  ['Jasmijn Chinees-Indisch Restaurant', 230, 'Zoetermeer Centrum West'],
#  ['Barbell', 292, 'Zoetermeer Centrum West'],
#  ['Holland & Barrett', 397, 'Zoetermeer Centrum West'],
#  ['Alles van Barbapapa Webwinkel Van', 445, 'Zoetermeer Centrum West'],
#  ['Barista Cafe', 482, 'Zoetermeer Centrum West'],
#  ['Restaurant Sahara', 749, 'Zoetermeer Centrum West'],
#  ['Restaurant "Altijd Lekker"', 634, 'Zoetermeer Centrum West'],
#  ["Mcdonald's Restaurant", 292, 'Zoetermeer Centrum West'],
#  ['Baran Market', 773, 'Zoetermeer Centrum West'],
#  ['Restaurant Le Mignon', 814, 'Zoetermeer Centrum West'],
#  ['Indonesisch Restaurant Sari', 833, 'Zoetermeer Centrum West'],
#  ['Bella Barista', 860, 'Zoetermeer Centrum West'],
#  ['Restaurant Achteraf', 875, 'Zoetermeer Centrum West'],
#  ['Baran Bakker', 913, 'Zoetermeer Centrum West'],
#  ['Hong Hij Restaurant', 930, 'Zoetermeer Centrum West'],
#  ['Restaurant Hong Yun', 947, 'Zoetermeer Centrum West'],
#  ['Chinees-Indisch Restaurant Regent', 956, 'Zoetermeer Centrum West'],
#  ['Restaurant Grillig', 959, 'Zoetermeer Centrum West'],
#  ['Restaurant Sandwich', 646, 'Zoetermeer Centrum West'],
#  ['Barbershop Sweetlake', 678, 'Zoetermeer Centrum West'],
#  ['Restaurant en Hotel de Sniep', 725, 'Zoetermeer Centrum West'],
#  ['Gonzales Barbecue Restaurants', 727, 'Zoetermeer Centrum West'],
#  ['Restaurant Il Carpaccio', 800, 'Zoetermeer Centrum West'],
#  ['Fresh Cuts Barbershop', 843, 'Zoetermeer Centrum West'],
#  ['Tasty Barbecue', 906, 'Zoetermeer Centrum West'],
#  ['Baran Banket Bakkerij', 924, 'Zoetermeer Centrum West'],
#  ['Dimitra Grieks Restaurant', 459, 'Woerden'],
#  ['De Baron Woerden Eetcafé en Zalencentrum', 186, 'Woerden'],
#  ['Restaurant Wyrda', 334, 'Woerden'],
#  ['Elpitha Grieks Restaurant', 673, 'Woerden'],
#  ['Restaurant De Markies', 601, 'Woerden'],
#  ['Bar @ Best Western Woerden', 265, 'Woerden'],
#  ['Restaurant De Beren Woerden', 364, 'Woerden'],
#  ['Baron kantoor', 394, 'Woerden'],
#  ['Fnv Bar', 422, 'Woerden'],
#  ['Restaurant Weddesteyn', 433, 'Woerden'],
#  ['Chinees-Indisch Restaurant Oriental Parel', 507, 'Woerden'],
#  ['Pizzeria Restaurant Bella Milano', 535, 'Woerden'],
#  ['Restaurant 2 Op 12', 593, 'Woerden'],
#  ['Barbier De', 607, 'Woerden'],
#  ['Reehorst Café Restaurant De', 615, 'Woerden'],
#  ["Barbara's Afscheidsfeestje", 619, 'Woerden'],
#  ['Mobiele Barista', 637, 'Woerden'],
#  ["Kir's Cocktail Bar", 765, 'Woerden'],
#  ['Italiaans Restaurant Mennoti', 864, 'Woerden'],
#  ["Menno's Barbiershop", 870, 'Woerden'],
#  ['Holland & Barrett', 557, 'Woerden'],
#  ["Restaurant 't Hof", 662, 'Woerden'],
#  ['Mobiele Barista', 4153, 'Woerden'],
#  ['Grieks Specialiteiten Restaurant Kreta', 259, 'Almelo'],
#  ['Nielz Café & Restaurant', 422, 'Almelo'],
#  ['Restaurant chronos', 97, 'Almelo'],
#  ["Restaurant Wetshuys Taveerne 't", 535, 'Almelo'],
#  ['Bar Biertje', 510, 'Almelo'],
#  ['Akropolis Griekspecialiteiten Restaurant', 528, 'Almelo'],
#  ['Bartelshoek', 540, 'Almelo'],
#  ['Restaurant China Delight', 274, 'Almelo'],
#  ['Chinees Specialiteiten Restaurant Hong Hua', 646, 'Almelo'],
#  ['Ibiza Almelo | Club - Restaurant - Lounge', 662, 'Almelo'],
#  ['Roberto Pizzeria Da/Restaurant Valentino', 675, 'Almelo'],
#  ['Restaurant De Sociëteit', 676, 'Almelo'],
#  ['NJOY Club en Tapas Bar', 700, 'Almelo'],
#  ['Traditionele Barbershop', 764, 'Almelo'],
#  ['Barbershop Robek', 777, 'Almelo'],
#  ['Barber Shop', 788, 'Almelo'],
#  ['Restaurant Balkan', 528, 'Almelo'],
#  ['Bar @ Animecon', 845, 'Almelo'],
#  ['Holland & Barrett', 539, 'Almelo'],
#  ['Apollon Grieks Specialiteiten Restaurant', 586, 'Almelo'],
#  ['Mexicaans Restaurant El Mundo', 594, 'Almelo'],
#  ['Pizzeria Restaurant Pino', 627, 'Almelo'],
#  ['Molen Restaurant Mesopotamische/Koerdische Specialiteiten De',
#   652,
#   'Almelo'],
#  ['Barzoi Vastgoed Adviseurs', 654, 'Almelo'],
#  ['Bargru Comp. en Randapparatuur', 746, 'Almelo'],
#  ['Barbershop', 777, 'Almelo'],
#  ['Bar Dijkstra', 710, 'Duiven '],
#  ['Bakker Bart', 735, 'Duiven '],
#  ['Turks Restaurant Saray', 824, 'Duiven '],
#  ['Bills Barn', 871, 'Duiven '],
#  ['Mytilini Grieks Specialiteiten Restaurant', 951, 'Duiven '],
#  ['Holland & Barrett', 714, 'Duiven '],
#  ['Restaurant Satéhuis', 320, 'OV-ebike Groningen'],
#  ['Restaurant WEEVA', 518, 'OV-ebike Groningen'],
#  ['Italia Pizzeria Restaurant', 465, 'OV-ebike Groningen'],
#  ['Japans Restaurant HANASATO', 369, 'OV-ebike Groningen'],
#  ['Restaurant Mendini', 94, 'OV-ebike Groningen'],
#  ['OMalleys Irish Pub & Restaurant', 578, 'OV-ebike Groningen'],
#  ['Vive la Vie (Restaurant Vive la Vie)', 638, 'OV-ebike Groningen'],
#  ['Groninger Museumcafé & Italiaans Restaurant', 102, 'OV-ebike Groningen'],
#  ['Pacific Aussie Pub & BBQ Restaurant', 587, 'OV-ebike Groningen'],
#  ['Cantina Mexicana Mexicaans Restaurant', 612, 'OV-ebike Groningen'],
#  ['Moro Restaurant', 690, 'OV-ebike Groningen'],
#  ['Boccaccio Bottega Toscana Restaurant', 691, 'OV-ebike Groningen'],
#  ["Stadscafé Restaurant 't Feithhuis", 845, 'OV-ebike Groningen'],
#  ['Sushi Bar', 223, 'OV-ebike Groningen'],
#  ['Flinders Café Restaurant Groningen Schuitendiep',
#   880,
#   'OV-ebike Groningen'],
#  ['Café bar poolcentrum Streetlife', 729, 'OV-ebike Groningen'],
#  ['Lash & Brow Bar', 384, 'OV-ebike Groningen'],
#  ['Restaurant M', 573, 'OV-ebike Groningen'],
#  ['Frigge Promenade Lunchroom Restaurant', 479, 'OV-ebike Groningen'],
#  ['Restaurant Gunes', 642, 'OV-ebike Groningen'],
#  ['Restaurant Muze', 645, 'OV-ebike Groningen'],
#  ['Napoli Pizzeria Restaurant', 800, 'OV-ebike Groningen'],
#  ['Bodega Restaurant De Apedans', 501, 'OV-ebike Groningen'],
#  ['Bar Parkweg', 505, 'OV-ebike Groningen'],
#  ['Tel Aviv Israëlisch Restaurant', 513, 'OV-ebike Groningen'],
#  ['Bar Golden Fust', 778, 'OV-ebike Groningen'],
#  ['Dipper Restaurant-Café', 553, 'OV-ebike Groningen'],
#  ['Hema Restaurant', 557, 'OV-ebike Groningen'],
#  ['Taberna Caldopenas Tapas Restaurant', 723, 'OV-ebike Groningen'],
#  ['Restaurant Digibites', 646, 'OV-ebike Groningen'],
#  ['Tekinev Restaurant', 666, 'OV-ebike Groningen'],
#  ['Restaurant De Beren Groningen', 711, 'OV-ebike Groningen'],
#  ['Restaurant Cave Oporto', 717, 'OV-ebike Groningen'],
#  ['Restaurant zum Ballerkamp', 737, 'OV-ebike Groningen'],
#  ['Caïro Café Restaurant', 751, 'OV-ebike Groningen'],
#  ['Pop-up restaurant Gro-eten', 756, 'OV-ebike Groningen'],
#  ['Tijdloos Restaurant', 782, 'OV-ebike Groningen'],
#  ['Naberhof Café Restaurant De', 808, 'OV-ebike Groningen'],
#  ['Babylon Restaurant Pizzeria', 984, 'OV-ebike Groningen'],
#  ['Restaurant de Haan', 852, 'OV-ebike Groningen'],
#  ['Spices Indiaas Restaurant', 905, 'OV-ebike Groningen'],
#  ['RuG Academia Restaurant', 911, 'OV-ebike Groningen'],
#  ['´t Koetshuys Restaurant & Bar Groningen', 915, 'OV-ebike Groningen'],
#  ['Restaurant Elanderhuis', 930, 'OV-ebike Groningen'],
#  ['Christiaans Restaurant', 985, 'OV-ebike Groningen'],
#  ['Cervantes Bar Bodega Restaurant', 697, 'OV-ebike Groningen'],
#  ['Restaurant Dokter Bart', 789, 'OV-ebike Groningen'],
#  ['Bar-Restaurant Robuust', 898, 'OV-ebike Groningen'],
#  ['Bakker Bart', 81, 'Lelystad Centrum'],
#  ['Restaurant Sorrento', 584, 'Lelystad Centrum'],
#  ['Restaurant Vuur', 289, 'Lelystad Centrum'],
#  ['Restaurant Flames', 289, 'Lelystad Centrum'],
#  ['Chinees Vegetarisch Restaurant Yuan', 168, 'Lelystad Centrum'],
#  ['Restaurant UNO Lelystad', 179, 'Lelystad Centrum'],
#  ['Restaurant Monica & Winston', 194, 'Lelystad Centrum'],
#  ['HJ Family Restaurant', 219, 'Lelystad Centrum'],
#  ['Restaurant Silver Wine And Dine', 228, 'Lelystad Centrum'],
#  ['Hema Restaurant Lelystad', 241, 'Lelystad Centrum'],
#  ['Broodjes Bar Lelystad', 281, 'Lelystad Centrum'],
#  ['Bar Bodega La Cave', 312, 'Lelystad Centrum'],
#  ["Exqi's Bar & Terrace", 359, 'Lelystad Centrum'],
#  ['Lekkerbek Snackbar Restaurant De', 404, 'Lelystad Centrum'],
#  ['Restaurant Lelystad', 537, 'Lelystad Centrum'],
#  ['Holland & Barrett', 227, 'Lelystad Centrum'],
#  ['Grand Café Restaurant Vier Engelen', 270, 'Lelystad Centrum'],
#  ['Plaza Bar La', 635, 'Lelystad Centrum'],
#  ['Bar Amigues', 637, 'Lelystad Centrum'],
#  ['Haje Restaurants De Lepelaar Bv', 825, 'Lelystad Centrum'],
#  ['Cafetaria Petit Restaurant Happy', 878, 'Lelystad Centrum'],
#  ['Barends Sport', 153, 'Voorhout'],
#  ["Ro's Barbershop", 153, 'Voorhout'],
#  ['China Chinees-Indisch Restaurant', 192, 'Voorhout'],
#  ['Barbara van Eeden - Diëtist', 401, 'Voorhout'],
#  ['Restaurant Asian Cuisine Oosthout', 535, 'Voorhout'],
#  ['Chinees restaurant Oosthoutplein', 535, 'Voorhout'],
#  ['Heineken Bar', 644, 'Voorhout'],
#  ['Barbel Coiffures', 321, 'Voorhout'],
#  ['Dam Verwarming Sanitair en Dakwerk Barry van', 801, 'Voorhout'],
#  ['L.H. Barrau Pensioenadviseur', 943, 'Voorhout'],
#  ['FLOC Restaurant', 305, 'Nijmegen Goffert'],
#  ['Restaurant Breeze', 988, 'Nijmegen Goffert'],
#  ['Bar Company', 798, 'Nijmegen Goffert'],
#  ['De Baron Acupunctuur', 932, 'Nijmegen Goffert'],
#  ['Restaurant Ninety', 981, 'Nijmegen Goffert'],
#  ['Restaurant Flow | Sanadome Hotel & Spa Nijmegen', 997, 'Nijmegen Goffert'],
#  ['Gitaarleraar Bart', 584, 'Nijmegen Goffert'],
#  ['Minos Pallas Grieks Restaurant', 631, 'Heerhugowaard'],
#  ['Menu Bar', 125, 'Heerhugowaard'],
#  ['Petit Restaurant Aangenaam', 213, 'Heerhugowaard'],
#  ['Restaurant Proeverij Gewoon Lekker', 375, 'Heerhugowaard'],
#  ['HYUNDAI Autobedrijf Dirk Barten', 438, 'Heerhugowaard'],
#  ['Barten Heerhugowaard', 554, 'Heerhugowaard'],
#  ['Restaurant De Beren Heerhugowaard', 616, 'Heerhugowaard'],
#  ['Chinees Restaurant Libelle', 678, 'Heerhugowaard'],
#  ['Reggies Beer Bar', 760, 'Heerhugowaard'],
#  ['Restaurants in jouw Stad - Noord Holland', 374, 'Heerhugowaard'],
#  ['Restaurant De Filosoof', 768, 'Heerhugowaard'],
#  ['warrie knarrie Restaurant', 800, 'Heerhugowaard'],
#  ['De Barnsteen', 802, 'Heerhugowaard'],
#  ['Goya,, Sushi Grill Restaurant', 814, 'Heerhugowaard'],
#  ['Jules Hotel Restaurant', 423, 'Heerhugowaard'],
#  ['Bakker Bart', 846, 'Heerhugowaard'],
#  ['Barnsteen 44', 870, 'Heerhugowaard'],
#  ["Eddy's Noten Bar", 464, 'Heerhugowaard'],
#  ['Thuis, Barnsteen', 895, 'Heerhugowaard'],
#  ['Holland & Barrett', 658, 'Heerhugowaard'],
#  ['Benefit Cosmetics BrowBar', 808, 'Heerhugowaard'],
#  ['Barsolo', 921, 'Heerhugowaard'],
#  ['Bar Beton Rijnsweerd', 190, 'Utrecht Rijnsweerd'],
#  ['Bar Lot', 223, 'Utrecht Rijnsweerd'],
#  ["Emma's Restaurant", 397, 'Utrecht Rijnsweerd'],
#  ['Restaurant De Beerekuil', 573, 'Utrecht Rijnsweerd'],
#  ['Begraafplaats St Barbara', 698, 'Utrecht Rijnsweerd'],
#  ['Restaurant-Brasserie Vlonders', 873, 'Utrecht Rijnsweerd'],
#  ['Begraafplaats St Barbara', 778, 'Utrecht Rijnsweerd'],
#  ['Dental Care Willem Barentsz', 842, 'Utrecht Rijnsweerd'],
#  ['Willem Barentszstraat', 992, 'Utrecht Rijnsweerd'],
#  ['Groenesteijn Restaurant BV', 627, 'Utrecht Rijnsweerd'],
#  ['Residence Barno', 703, 'Utrecht Rijnsweerd'],
#  ['HouwersBartels', 834, 'Utrecht Rijnsweerd'],
#  ['Barkey Wolf & Sprong Bedrijfshuisvesting', 886, 'Utrecht Rijnsweerd'],
#  ['Restaurant Tapa Tapa', 254, 'Zeist'],
#  ['Vof Douwe Dabbert Cafe Bar', 75, 'Zeist'],
#  ['Monterosso Pizzeria Restaurant', 570, 'Zeist'],
#  ['Japans Sushi Restaurant Ichi', 206, 'Zeist'],
#  ['Dell Italia Restaurant', 349, 'Zeist'],
#  ["Barbecue Rest. En Pannekoekenhuis 't Jagershuys", 894, 'Zeist'],
#  ['Vof Douwe Dabbert Cafe Bar', 75, 'Zeist'],
#  ['Lin-Fa Chinees-Indisch Restaurant', 399, 'Zeist'],
#  ['Buddha Restaurant', 572, 'Zeist'],
#  ['Gonzales Barbecue Restaurant Zeist', 440, 'Zeist'],
#  ['restaurant bij zwembad Dijnselburg', 472, 'Zeist'],
#  ['Restaurant The Fusion Club', 541, 'Zeist'],
#  ['Restaurant Jeruzalem', 223, 'Zeist'],
#  ['Monterosso Pizzeria Restaurant', 574, 'Zeist'],
#  ['Barista Cafe Zeist', 579, 'Zeist'],
#  ['Brood- en Banketbakkerij C van Barneveld', 580, 'Zeist'],
#  ['KantoorHet Ovaal, Bartimeus', 597, 'Zeist'],
#  ["Bell's Restaurant", 648, 'Zeist'],
#  ['Brasserie Twist Of Flavours Restaurant & Catering', 706, 'Zeist'],
#  ['Grieks Specialiteiten Restaurant Sirtaki', 709, 'Zeist'],
#  ['Holland & Barrett', 387, 'Zeist'],
#  ['Restaurant Rutteman', 801, 'Zeist'],
#  ['Hoveniersbedrijf Wilfried Barten', 898, 'Zeist'],
#  ['Vermaat Restaurant Ziekenhuis', 922, 'Zeist'],
#  ["Backhuys Restaurant en Stoetlokaal 't", 742, 'Winschoten'],
#  ['restaurant Oldambt', 347, 'Winschoten'],
#  ['Locomotion Bar', 54, 'Winschoten'],
#  ['Ying Ping Chinees-Indisch Restaurant', 387, 'Winschoten'],
#  ['Bakker Bart', 392, 'Winschoten'],
#  ['Holland & Barrett Israelplen 9 Winschoten', 394, 'Winschoten'],
#  ['Japans Restaurant Hakki', 445, 'Winschoten'],
#  ['Gril Restaurant Shalom', 455, 'Winschoten'],
#  ['Hotel Restaurant Victoria', 469, 'Winschoten'],
#  ['Grieks Specialiteiten Restaurant Rhodos', 513, 'Winschoten'],
#  ['Pizzeria & Italiaans restaurant Bellissima', 535, 'Winschoten'],
#  ['Jongerencentr Bart', 595, 'Winschoten'],
#  ['V.O.F. Balkan Restaurant Makedonia', 773, 'Winschoten'],
#  ['Ying Ping Chinees-Indisch Restaurant', 400, 'Winschoten'],
#  ['Faith Bar', 405, 'Winschoten'],
#  ['Holland & Barrett', 441, 'Winschoten'],
#  ['Grieks Restaurant Athene', 544, 'Winschoten'],
#  ['Midi Petit Restaurant', 573, 'Winschoten'],
#  ['Nuevo Nescio, Spaans Restaurant', 616, 'Winschoten'],
#  ['Barbier, Intercoiffure De', 644, 'Winschoten'],
#  ['De Cactus Mexicaans Restaurant', 773, 'Winschoten'],
#  ['Petit-Restaurant De Tiggel', 867, 'Winschoten'],
#  ['Bart Videoproducties', 452, 'Haren'],
#  ['Restaurant Cafetaria Zaal Catering Astoria', 907, 'Haren'],
#  ['Pub Bar Café De', 885, 'Haren'],
#  ['Restaurant Cafetaria Zaal Catering Astoria', 920, 'Haren'],
#  ['Barbra', 982, 'Haren'],
#  ['Restaurant Zaal Catering Astoria', 544, 'Haren'],
#  ['Barzeker', 725, 'Haren'],
#  ['Café-Restaurant AALTJE', 486, 'Weesp'],
#  ['Restaurant Alhambra', 438, 'Weesp'],
#  ['T&B Barkruk', 315, 'Weesp'],
#  ['Chinees Restaurant Afhaalcentr Jumbo', 320, 'Weesp'],
#  ['Chido Streetfood Bar', 440, 'Weesp'],
#  ['Restaurant de Kruidenier', 469, 'Weesp'],
#  ['Cafe Restaurant De Kroon', 525, 'Weesp'],
#  ['Proeverij Restaurant De Kroon', 546, 'Weesp'],
#  ['Rimini Italiaans Restaurant', 657, 'Weesp'],
#  ['Torito Argentijns Grill-Restaurant', 399, 'Weesp'],
#  ['Restaurant WoningNet', 944, 'Weesp'],
#  ['Japans Restaurant TAO', 293, 'Enschede'],
#  ['Bluff Food & Bar', 354, 'Enschede'],
#  ['Tropen Restaurant De', 356, 'Enschede'],
#  ["Bölke Bar Discotheek Sauna 't", 300, 'Enschede'],
#  ['Carlina Zuid-Amerikaans Restaurant & Catering', 479, 'Enschede'],
#  ['Restaurant Joann', 192, 'Enschede'],
#  ['Olympic Grieks Bistro Restaurant', 234, 'Enschede'],
#  ['Hotel Restaurant Rodenbach', 503, 'Enschede'],
#  ['Bar Intercity Enschede', 264, 'Enschede'],
#  ['Breakfast Bar Intercity', 295, 'Enschede'],
#  ["Bölke Bar Discotheek Sauna 't", 309, 'Enschede'],
#  ['Magic Bar', 317, 'Enschede'],
#  ['Gehakt Ballen Bar', 331, 'Enschede'],
#  ['Chinees Specialiteiten Restaurant International', 590, 'Enschede'],
#  ['Camel Cafe Restaurant', 343, 'Enschede'],
#  ['Restaurant Lazuli', 492, 'Enschede'],
#  ['Restaurant-Pizzeria Sorrentino', 482, 'Enschede'],
#  ['Café - Restaurant Camel', 373, 'Enschede'],
#  ['Restaurant Le Soleil', 373, 'Enschede'],
#  ["MCE's Bar", 375, 'Enschede'],
#  ['Vermaat Restaurant', 382, 'Enschede'],
#  ['MST - Restaurant Ariënsplein', 432, 'Enschede'],
#  ['L.a. Dance bar', 440, 'Enschede'],
#  ['Griekse Specialiteiten Restaurant Thessaloniki', 457, 'Enschede'],
#  ['Restaurant Pinokio', 464, 'Enschede'],
#  ['Café Bar International', 466, 'Enschede'],
#  ['Kosie Restaurant', 490, 'Enschede'],
#  ['Hotel Restaurant Rodenbach BV', 492, 'Enschede'],
#  ['Carlina Zuid-Amerikaans Restaurant & Catering', 492, 'Enschede'],
#  ['Bar de Vrijheid Enschede', 532, 'Enschede'],
#  ['Wok Restaurant HAOHAO', 572, 'Enschede'],
#  ['Hotel Restaurant La Carretera', 229, 'Enschede'],
#  ['Maan Café Restaurant De Halve', 609, 'Enschede'],
#  ['Bar de Vrijheid Enschede', 635, 'Enschede'],
#  ['Amadeus Hotel Restaurant', 650, 'Enschede'],
#  ['Pizzeria Restaurant Toscana', 326, 'Enschede'],
#  ['Siam Thais Restaurant', 355, 'Enschede'],
#  ['Japans Restaurant Kimono', 361, 'Enschede'],
#  ['Restaurant Havana - Marokkaanse en Spaanse Specialiteiten Restaurant',
#   786,
#   'Enschede'],
#  ['Restaurant Ranayana', 417, 'Enschede'],
#  ['Tea restaurant', 844, 'Enschede'],
#  ['Restaurant De Brink', 408, 'P + R Utrecht Science Park (De Uithof)'],
#  ['Lavalamp bar', 305, 'P + R Utrecht Science Park (De Uithof)'],
#  ['Sodexo restaurant - HU FEM', 306, 'P + R Utrecht Science Park (De Uithof)'],
#  ['Sodexo restaurant HU FG', 312, 'P + R Utrecht Science Park (De Uithof)'],
#  ['Sodexo restaurant HU FCJ', 333, 'P + R Utrecht Science Park (De Uithof)'],
#  ['PL97 Restaurant', 410, 'P + R Utrecht Science Park (De Uithof)'],
#  ['Huffels Restaurant', 434, 'P + R Utrecht Science Park (De Uithof)'],
#  ['Restaurant De Toverstaf', 742, 'P + R Utrecht Science Park (De Uithof)'],
#  ['Restaurant Bar Luz', 658, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['1910 Restaurant-bar', 747, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Restaurant Giornale', 89, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Japans Restaurant Yokohama', 83, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Sizzling Restaurant', 123, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['The Pool Bar', 64, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Grill&Bar Dommel 18', 150, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['VANE Skybar Bar', 172, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Restaurant Mint', 349, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Restaurant Café De Effenaar',
#   227,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['XU Noodle Bar Eindhoven', 535, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Indonesia Indonesisch Restaurant',
#   461,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Pullman Cocagne Restaurant', 421, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Bar & Restaurant Vestdijk47',
#   421,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Restaurant Sicilia Eindhoven',
#   136,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Lithos Grieks Specialiteiten Restaurant',
#   614,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['The Little One Bar', 471, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Restaurant Dijk9', 869, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ["Pullman's Bar", 409, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Queen Hotel Restaurant', 329, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Bar Bistro Calypso', 716, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Vascobelo V-bar Eindhoven', 683, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Centraal Café-Restaurant', 341, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Restaurant Wiesen', 594, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Sinema Turkish Restaurant', 121, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Berlin Bar 5611', 735, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Turks Restaurant Dommelstraat',
#   148,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['At the Movies Restaurant and Bar',
#   188,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ["Café Bar 't Lempke", 602, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Vintage Restaurant', 613, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Volder Restaurant De', 265, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Restaurant Boon', 809, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Surabaya Restaurant Indonesische Specialiteiten',
#   553,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Chinees Restaurant "Kam Po"',
#   912,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Restaurant Lumen', 457, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Tijdelijk Restaurant Strijp-S',
#   345,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Café Restaurant Eindhoven', 391, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Restaurant Lara', 543, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Restaurant Avant-Garde Van Groeninge',
#   957,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['restaurant the Prince', 786, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Bar/Restaurant Inntel Hotels Art Eindhoven',
#   463,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Smeagol Argentijns Grill Restaurant',
#   548,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Queen Anne Restaurant - Edinburgh Castle',
#   565,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Arigato restaurant, bar & lounge',
#   669,
#   'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Hey Days Restaurant/Bar', 673, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Pop-up Bar Restaurant LUCE', 737, 'Eindhoven Centraal zuidzijde (centrum)'],
#  ['Piccalily Restaurant', 130, 'Utrecht P+R Papendorp'],
#  ['Stork Restaurant', 544, 'Utrecht P+R Papendorp'],
#  ['Istanbul Restaurant', 571, 'Utrecht P+R Papendorp'],
#  ['Al-baraka', 837, 'Utrecht P+R Papendorp'],
#  ['Cupp (Barista Workshop & Training)', 908, 'Utrecht P+R Papendorp'],
#  ["Ani's Barbershop", 829, 'Utrecht P+R Papendorp'],
#  ['Al Baraka Patisserie', 864, 'Utrecht P+R Papendorp'],
#  ['Cafetaria-Bar STORIE', 392, 'Hoogezand Sappemeer'],
#  ['Akropolis Grieks Restaurant', 477, 'Hoogezand Sappemeer'],
#  ['Hachi Sushi & Grill Bar', 980, 'Diemen Zuid'],
#  ['Barba', 437, 'Diemen Zuid'],
#  ["Kale's Barakka", 741, 'Diemen Zuid'],
#  ['Istanbul Cafe Restaurant', 745, 'Diemen Zuid'],
#  ['Randstad illegale bar', 770, 'Diemen Zuid'],
#  ['Kapsalon The Barber', 386, 'Diemen Zuid'],
#  ['Tandoor BBQ restaurant', 841, 'Diemen Zuid'],
#  ['Bamboo Bar', 860, 'Diemen Zuid'],
#  ['Istanbul Grill Restaurant', 841, 'Diemen Zuid'],
#  ['Grand Café & Restaurant Bank de', 548, 'Bunnik'],
#  ['Sint Barbarakerk', 559, 'Bunnik'],
#  ['St. Barbara Kerk Bunnik', 609, 'Bunnik'],
#  ['Kerkhof Ste Barbara', 645, 'Bunnik'],
#  ['Barbaraschool', 906, 'Bunnik'],
#  ['Restaurant-Brasserie Bruynick (Mercure Hotel)', 647, 'Bunnik'],
#  ['Barbaraschool RK', 747, 'Bunnik'],
#  ['Restaurant Boas', 345, 'Deventer'],
#  ['Bakkerij Bart', 353, 'Deventer'],
#  ['Restaurant Jackies NYCuisine', 556, 'Deventer'],
#  ['Restaurant De Keizer', 325, 'Deventer'],
#  ['Bouwkunde Theater Restaurant', 608, 'Deventer'],
#  ['New King Tiu Chinees-Indisch Restaurant', 167, 'Deventer'],
#  ['New King Tiu Chinees-Indisch Restaurant', 171, 'Deventer'],
#  ['Da Mario Restaurant', 532, 'Deventer'],
#  ['Safak Turks Restaurant', 504, 'Deventer'],
#  ['FINCH bar', 208, 'Deventer'],
#  ['Hong Fong Chinees Japans Restaurant', 239, 'Deventer'],
#  ['Restaurant PP', 375, 'Deventer'],
#  ['Daltons Steakhouse Restaurant', 552, 'Deventer'],
#  ['Restaurant Vrijdag', 552, 'Deventer'],
#  ['Bar-Bistro De Rode Kater', 719, 'Deventer'],
#  ['Trinibra Sushi Bar', 352, 'Deventer'],
#  ['Gonzales Barbecue Restaurant', 463, 'Deventer'],
#  ['Italiaans Restaurant Mio Sogno', 465, 'Deventer'],
#  ['Sardegna Restaurant Pizzeria La', 465, 'Deventer'],
#  ['Trinibra Sushi Bar', 487, 'Deventer'],
#  ['New King Tiu Chinees-Indisch Restaurant', 498, 'Deventer'],
#  ['Bar Milano', 500, 'Deventer'],
#  ['Chez Antoinette Restaurant', 506, 'Deventer'],
#  ['Restaurant Mekong', 510, 'Deventer'],
#  ['Alm Café Bar De', 510, 'Deventer'],
#  ['ZUS. Bar-Kitchen', 569, 'Deventer'],
#  ['Loev Bar Bistro', 612, 'Deventer'],
#  ['Fastfood Restaurant Kumpiria', 291, 'Deventer'],
#  ['Hotel Restaurant Pension De Duimpoort', 704, 'Deventer'],
#  ['Restaurant Vermeer', 706, 'Deventer'],
#  ['Bar De Tobbe', 765, 'Deventer'],
#  ["jonne's Bar & Baby Care", 920, 'Deventer'],
#  ['Restaurant Keizerskroon', 499, 'Deventer'],
#  ["Pannenkoekenhuis 't Hollands Restaurant", 500, 'Deventer'],
#  ['Restaurant In De Golden Helm', 514, 'Deventer'],
#  ["Viktor's Balkan Restaurant Postojna", 537, 'Deventer'],
#  ["Restaurant D' Ouwe Wijze", 537, 'Deventer'],
#  ['Floors Café Restaurant', 564, 'Deventer'],
#  ['Restaurant Nanking', 564, 'Deventer'],
#  ['My Thai_Thai Food Bar & Lounge', 564, 'Deventer'],
#  ['Restaurant De Paap', 584, 'Deventer'],
#  ['Club Restaurant Moskou', 601, 'Deventer'],
#  ['Bar-Bistro De Rode Kater', 618, 'Deventer'],
#  ['Restaurant/Brasserie De Hazelaar', 714, 'Deventer'],
#  ['Lansink Tuindorphotel t Kouwenbergs Restaurant',
#   976,
#   'Hengelo Gezondheidspark'],
#  ['2 Tight Barbershop', 487, 'Hengelo Gezondheidspark'],
#  ['Personal Bar', 615, 'Hengelo Gezondheidspark'],
#  ['Barbara Klaver Huidverzorgingsinstituut', 863, 'Hengelo Gezondheidspark'],
#  ["Tuindorp Café Restaurant 't", 879, 'Hengelo Gezondheidspark'],
#  ['Tiki Bar Jules & Lara', 945, 'Hengelo Gezondheidspark'],
#  ['Restaurant Kouwenberg', 959, 'Hengelo Gezondheidspark'],
#  ["Tuindorp Café Restaurant 't", 879, 'Hengelo Gezondheidspark'],
#  ['Restaurant Juliaantje', 587, 'Deventer Boerhavelaan'],
#  ['Restaurant BuitenSporig', 83, 'Tiel'],
#  ['Grieks Specialiteiten Restaurant Akropolis', 73, 'Tiel'],
#  ['Bakker Bart', 693, 'Tiel'],
#  ['Restaurant Puur Betuwe', 567, 'Tiel'],
#  ['Holland & Barrett (De Tuinen)', 739, 'Tiel'],
#  ['Bistro Bar JUS', 895, 'Tiel'],
#  ['Twins Restaurant', 908, 'Tiel'],
#  ['The SPOT Kitchen & Bar', 918, 'Tiel'],
#  ['Barla Eetcafé', 919, 'Tiel'],
#  ['Haarstudio Barbershop', 958, 'Tiel'],
#  ['Holland & Barrett', 852, 'Tiel'],
#  ['Steeg Café Bar In de', 924, 'Tiel'],
#  ['Hong Kong Chinees-Indisch Restaurant', 976, 'Tiel'],
#  ["Restaurant L'Etoile (onderdeel van het Teaching Hotel Chateau Bethlehem)",
#   596,
#   'Maastricht Noord'],
#  ['PLATO bar', 454, 'Maastricht Noord'],
#  ['Amphytrion bar', 483, 'Maastricht Noord'],
#  ["Cafe Bar 't Pannesjop", 488, 'Maastricht Noord'],
#  ['Bar Le Coin', 598, 'Maastricht Noord'],
#  ['4 Seasons Restaurant', 609, 'Maastricht Noord'],
#  ['Restaurant Four Seasons', 609, 'Maastricht Noord'],
#  ['Pop up restaurant HMSM', 624, 'Maastricht Noord'],
#  ["Restaurant L'Étoile", 699, 'Maastricht Noord'],
#  ['Barbershop "Luc"', 863, 'Maastricht Noord'],
#  ["Restaurant L'Etoile Teaching Hotel , Hotel Management School Maastricht",
#   699,
#   'Maastricht Noord'],
#  ['El Fadila Marokkaanse Specialiteiten Restaurant', 806, 'Maastricht Noord'],
#  ["Strada Eric's bar La", 746, 'Goes'],
#  ['Restaurant Margarita', 287, 'Goes'],
#  ['Restaurant De Landbouw', 625, 'Goes'],
#  ['Steenen Brug Pannenkoeken Restaurant De', 459, 'Goes'],
#  ['The Juice Bar', 526, 'Goes'],
#  ['Trattoria La Barca Goes', 540, 'Goes'],
#  ['Cafe Bar Kerkuul', 552, 'Goes'],
#  ['Bakker Bart', 561, 'Goes'],
#  ['Restaurant Hector', 774, 'Goes'],
#  ['Amadore Hotel Restaurant Jersey', 648, 'Goes'],
#  ['Restaurant Codium', 649, 'Goes'],
#  ['The Nail Bar', 652, 'Goes'],
#  ['Barbarella', 662, 'Goes'],
#  ['Bar Le Clochard', 677, 'Goes'],
#  ['Witte Lelie De Kook Restaurant', 717, 'Goes'],
#  ['Coffee Bar Shine', 725, 'Goes'],
#  ['The London Barbers', 732, 'Goes'],
#  ['Club Barbarella Tevens Escortservice', 733, 'Goes'],
#  ['Restaurant Bellevue Vof', 400, 'Goes'],
#  ['Bon Vivant, Restaurant', 400, 'Goes'],
#  ['Chinees-Indisch Restaurant Nian Hao V.o.f.', 401, 'Goes'],
#  ['Herenkapsalon & barbier Bogers', 902, 'Goes'],
#  ['Bandit Barbers', 488, 'Goes'],
#  ['Goes, Hotel-Restaurant', 511, 'Goes'],
#  ['Bart, Elektrotechn Install Buro', 526, 'Goes'],
#  ['Holland & Barrett', 598, 'Goes'],
#  ['Restaurant Jan', 751, 'Goes'],
#  ['The Nail Bar Goes', 676, 'Goes'],
#  ['Restaurant De Zeekoe', 711, 'Goes'],
#  ['Rumah Makan Melati Baru BV', 75, 'Amersfoort Mondriaanplein'],
#  ['Bar Beton Amersfoort Centraal', 85, 'Amersfoort Mondriaanplein'],
#  ['Barndoor Gathering and Vintage VW Show', 91, 'Amersfoort Mondriaanplein'],
#  ['Parking P R Barchman Wuytierslaan', 287, 'Amersfoort Mondriaanplein'],
#  ['The Street Food Bar', 938, 'Amersfoort Mondriaanplein'],
#  ['Merlot Restaurant & Wijnbar', 975, 'Amersfoort Mondriaanplein'],
#  ['Thais & Vietnamees Restaurant Nón Lá', 375, 'Amersfoort Mondriaanplein'],
#  ['Vide Restaurant Agis', 412, 'Amersfoort Mondriaanplein'],
#  ['Baronian Design', 574, 'Amersfoort Mondriaanplein'],
#  ['Fietsenstalling Barchman Wuytierslaan', 585, 'Amersfoort Mondriaanplein'],
#  ['Restaurant “Clockwise”', 597, 'Amersfoort Mondriaanplein'],
#  ["Verdi's Pizzeria Restaurant", 617, 'Amersfoort Mondriaanplein'],
#  ['Dido (tijdelijk restaurant)', 631, 'Amersfoort Mondriaanplein'],
#  ['Tollius Restaurant & Catering', 637, 'Amersfoort Mondriaanplein'],
#  ['Bar Conventus Comus', 670, 'Amersfoort Mondriaanplein'],
#  ['Timeless Bar', 617, 'Amersfoort Mondriaanplein'],
#  ['Barefood Coffee', 754, 'Amersfoort Mondriaanplein'],
#  ['DLC Restaurant', 757, 'Amersfoort Mondriaanplein'],
#  ['Restaurant De Beren Amersfoort', 848, 'Amersfoort Mondriaanplein'],
#  ['Sate Bar', 879, 'Amersfoort Mondriaanplein'],
#  ['Twice Bar Bara Bara Bere Bere', 938, 'Amersfoort Mondriaanplein'],
#  ['WestSingel Lounge en Restaurant', 957, 'Amersfoort Mondriaanplein'],
#  ['Turks Restaurant Dostlar', 963, 'Amersfoort Mondriaanplein'],
#  ['Brutus Café Bar', 981, 'Amersfoort Mondriaanplein'],
#  ['Buffetcatering Restaurant Azië Chinees Specialiteiten',
#   982,
#   'Amersfoort Mondriaanplein'],
#  ['Succes Bar', 995, 'Amersfoort Mondriaanplein'],
#  ['Double Dutch Bar-Café', 551, 'Amersfoort Mondriaanplein'],
#  ['The Barber Shop', 1065, 'Amersfoort Mondriaanplein'],
#  ['De Balans Bar (Amicitia Food Village)', 831, 'Amersfoort Mondriaanplein'],
#  ['Restaurant Het Croontje', 945, 'Amersfoort Mondriaanplein'],
#  ['Restaurant Ruig', 233, 'Utrecht Centraal Jaarbeursplein'],
#  ['Bar Beton CS', 89, 'Utrecht Centraal Jaarbeursplein'],
#  ['Seafood Bar Utrecht', 281, 'Utrecht Centraal Jaarbeursplein'],
#  ['Bar Centraal', 178, 'Utrecht Centraal Jaarbeursplein'],
#  ['Petit-Restaurant / Lunchroom Deluxe',
#   351,
#   'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Claar', 607, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant VIS&MEER', 659, 'Utrecht Centraal Jaarbeursplein'],
#  ['Cafe- Restaurant Catherijnehof Bv', 102, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Blauw Utrecht', 819, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Saffraan', 765, 'Utrecht Centraal Jaarbeursplein'],
#  ['Casa Di David Restaurant', 834, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant NH Hotel', 185, 'Utrecht Centraal Jaarbeursplein'],
#  ['Graaf Floris Café Restaurant', 906, 'Utrecht Centraal Jaarbeursplein'],
#  ['JEU de boules bar', 727, 'Utrecht Centraal Jaarbeursplein'],
#  ['PK Bar & Kitchen Utrecht', 748, 'Utrecht Centraal Jaarbeursplein'],
#  ['Burger Bar Utrecht', 908, 'Utrecht Centraal Jaarbeursplein'],
#  ["Queen's Restaurant", 254, 'Utrecht Centraal Jaarbeursplein'],
#  ['De Utrechter stadsbrasserie en bar',
#   554,
#   'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Grote Markt', 274, 'Utrecht Centraal Jaarbeursplein'],
#  ['Dim Sum Bar Pacifica', 901, 'Utrecht Centraal Jaarbeursplein'],
#  ['Bar Cava', 872, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Smaak', 660, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant De Markt', 653, 'Utrecht Centraal Jaarbeursplein'],
#  ['Bar Beton Centraal', 399, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Tafel aan de Gracht', 728, 'Utrecht Centraal Jaarbeursplein'],
#  ['Bar Restaurant Walden', 956, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Loof', 950, 'Utrecht Centraal Jaarbeursplein'],
#  ['Levantine Restaurant & Steak House',
#   429,
#   'Utrecht Centraal Jaarbeursplein'],
#  ['Ethiopisch Restaurant Sunshine', 918, 'Utrecht Centraal Jaarbeursplein'],
#  ['Bijenkorf restaurant la Ruche', 715, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Salaam', 640, 'Utrecht Centraal Jaarbeursplein'],
#  ['Petit Restaurant Royal', 497, 'Utrecht Centraal Jaarbeursplein'],
#  ['Mobiel Restaurant Lust', 502, 'Utrecht Centraal Jaarbeursplein'],
#  ['Pop-up Restaurant Happietaria Utrecht',
#   509,
#   'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Rhodos', 929, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Lisboa', 672, 'Utrecht Centraal Jaarbeursplein'],
#  ['Liefs restaurant', 563, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Zuiver', 755, 'Utrecht Centraal Jaarbeursplein'],
#  ['BUNK Hotel Restaurant', 598, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Cvc Domstad', 606, 'Utrecht Centraal Jaarbeursplein'],
#  ['Passant Petit Restaurant Lunchroom Le',
#   619,
#   'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Karel 5', 745, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Cozinja', 691, 'Utrecht Centraal Jaarbeursplein'],
#  ['Restaurant Bistronome Des Arts', 911, 'Utrecht Centraal Jaarbeursplein'],
#  ['Sarban Afghaans Restaurant', 778, 'Utrecht Centraal Jaarbeursplein'],
#  ['restaurant De Zwaan', 512, 'Geldrop'],
#  ["Baron Z'n Hof", 264, 'Geldrop'],
#  ['Restaurant SMAEK', 484, 'Geldrop'],
#  ['Bartels Kapsalon Toni', 403, 'Geldrop'],
#  ['Noud Bartels Stukadoorsbedrijf', 438, 'Geldrop'],
#  ["Grand Cafe Restaurant D'n Brabander", 479, 'Geldrop'],
#  ['The Bank Bar', 493, 'Geldrop'],
#  ['Bart Bakkerij', 509, 'Geldrop'],
#  ['MKA Barkhuysen Chirurgie', 513, 'Geldrop'],
#  ['Clown Café-Bar De', 561, 'Geldrop'],
#  ['Sicilia Restaurant', 562, 'Geldrop'],
#  ['Barbershop', 573, 'Geldrop'],
#  ['Barten Sneltransport vof', 667, 'Geldrop'],
#  ['Square Restaurant', 685, 'Geldrop'],
#  ["Jo's Barke", 718, 'Geldrop'],
#  ['Chinees Indisch Restaurant Azie', 755, 'Geldrop'],
#  ['Zusters Van Barmhartigheid', 534, 'Geldrop'],
#  ['Irodion Griekse Specialiteiten Restaurant', 571, 'Geldrop'],
#  ['Grieks Restaurant Plaka', 724, 'Geldrop'],
#  ['Bart Zuid', 766, 'Geldrop'],
#  ['Chinees-Indisch Restaurant Ocean City', 607, 'Den Helder Zuid'],
#  ['Maud Barriel', 843, 'Den Helder Zuid'],
#  ['Lotus Chinees-Kantonees Spec Restaurant', 556, 'Den Helder Zuid'],
#  ['V.S. Di Bartolo', 722, 'Den Helder Zuid'],
#  ['Restaurant Paping', 141, 'Ommen'],
#  ['Vonck Restaurant', 111, 'Ommen'],
#  ['De Zon Hotel & Restaurant', 839, 'Ommen'],
#  ['Wildthout Hotel & Restaurant', 587, 'Ommen'],
#  ['HEMA restaurant', 955, 'Ommen'],
#  ["Murad's Barbershop", 957, 'Ommen'],
#  ["Restaurant 't Burgemeestertje", 920, 'Ommen'],
#  ['Barista Café Leidsche Rijn', 160, 'Utrecht Leidsche Rijn'],
#  ['Bar Iberico', 219, 'Utrecht Leidsche Rijn'],
#  ['Holland & Barrett', 181, 'Utrecht Leidsche Rijn'],
#  ['Eetcafé de Baron', 215, 'Utrecht Leidsche Rijn'],
#  ['Meet & Eat Utrecht - Restaurant & Zalencentrum',
#   275,
#   'Utrecht Leidsche Rijn'],
#  ['AC Restaurant Utrecht', 303, 'Utrecht Leidsche Rijn'],
#  ['O-bar', 543, 'Utrecht Leidsche Rijn'],
#  ['Sky Bar', 787, 'Utrecht Leidsche Rijn'],
#  ["McDonald's Restaurant & Mcdrive", 701, 'Utrecht Leidsche Rijn'],
#  ['Bart Broeze Photography', 744, 'Utrecht Leidsche Rijn'],
#  ['Barista Mobile', 899, 'Utrecht Leidsche Rijn'],
#  ['Barista Mobile t.h.o.d.n. Casabarista', 904, 'Utrecht Leidsche Rijn'],
#  ['Restaurant Eethuys-Cafe De Generaal', 105, 'Baarn'],
#  ['Promenade La Hotel Restaurant', 475, 'Baarn'],
#  ['Promenade La Hotel Restaurant', 475, 'Baarn'],
#  ['Prima Vera Italiaans Restaurant', 478, 'Baarn'],
#  ['Bakker Bart', 561, 'Baarn'],
#  ['Holland & Barrett', 564, 'Baarn'],
#  ['Lange Muur Chinees-Indisch Restaurant', 567, 'Baarn'],
#  ['Barbier Rogier', 588, 'Baarn'],
#  ['Olympia Grieks Restaurant', 601, 'Baarn'],
#  ['Chinees-Indisch Restaurant Peking', 731, 'Baarn'],
#  ['Hotel Restaurant Promenade', 471, 'Baarn'],
#  ['Cafe Bar Le Baron', 540, 'Baarn'],
#  ['Nefartite Restaurant Steakhouse', 823, 'Baarn'],
#  ['Restaurant Olive', 415, 'Vleuten'],
#  ['Happy Days Bar', 500, 'Vleuten'],
#  ['Restaurant Oost-West', 511, 'Vleuten'],
#  ['Vleutens Paleis Chinees-Indisch Specialiteiten Restaurant', 539, 'Vleuten'],
#  ['Royal Bar Eyckenstein', 564, 'Vleuten'],
#  ['Bart & Bart B.V.', 850, 'Vleuten'],
#  ['Restaurant De Buffel', 879, 'Vleuten'],
#  ['Cafe Restaurant De Tol', 511, 'Vleuten'],
#  ['Barbier Vleuten', 992, 'Vleuten'],
#  ['Barista Marlies', 871, 'Vleuten'],
#  ['Hema Restaurant', 368, 'Steenwijk'],
#  ['Tennessee American Bar&Grill', 399, 'Steenwijk'],
#  ['Café Caram-Bar', 425, 'Steenwijk'],
#  ['Bakker Bart', 429, 'Steenwijk'],
#  ['Grieks Specialiteiten Restaurant Rhodos', 430, 'Steenwijk'],
#  ['Rhodos Grill & Buffet Restaurant Steenwijk', 430, 'Steenwijk'],
#  ['Barbier', 434, 'Steenwijk'],
#  ['De Barbier Kapper voor de man', 446, 'Steenwijk'],
#  ['Shanghai Chinees-Indisch Restaurant', 451, 'Steenwijk'],
#  ['De Barbier Kapper voor de man', 462, 'Steenwijk'],
#  ['Dynasty Chinees Restaurant', 712, 'Steenwijk'],
#  ['Holland & Barrett', 344, 'Steenwijk'],
#  ['Chinees-Indisch Specialiteiten Restaurant Fong Shou', 387, 'Steenwijk'],
#  ['Restaurant Patijntje', 403, 'Steenwijk'],
#  ['Cafe Bar Uncle Sam', 441, 'Steenwijk'],
#  ['Fletcher Hotel-Restaurant Steenwijk', 904, 'Steenwijk'],
#  ['Restaurant Het Getij', 712, 'Steenwijk'],
#  ['Joulz/Stedin/Citytec BedrijfsRestaurant Albron', 59, 'Delft Zuid'],
#  ['Restaurant LR', 771, 'Delft Zuid'],
#  ['Barbecue Exclusief', 753, 'Delft Zuid'],
#  ['Bakker Bart', 760, 'Delft Zuid'],
#  ['Makro Restaurant', 861, 'Delft Zuid'],
#  ['Robbie,s BAR', 849, 'Delft Zuid'],
#  ['MPD Bar', 885, 'Delft Zuid'],
#  ['Barista Café', 401, 'Rijswijk'],
#  ['The Crown Restaurant', 92, 'Rijswijk'],
#  ['Restaurant Izmir', 387, 'Rijswijk'],
#  ['Restaurant Indonesisch Tjendrawasih', 294, 'Rijswijk'],
#  ['Grand Canteen Restaurant', 336, 'Rijswijk'],
#  ['Istanbul Restaurant', 345, 'Rijswijk'],
#  ['Barbershop Het Keldertje', 352, 'Rijswijk'],
#  ['Mili Restaurant', 358, 'Rijswijk'],
#  ['Restaurant El Mamma', 358, 'Rijswijk'],
#  ['Leds Restaurant', 371, 'Rijswijk'],
#  ['Furusato Teppanyaki Restaurant', 432, 'Rijswijk'],
#  ['Holland & Barrett', 448, 'Rijswijk'],
#  ['Chinees Indisch Restaurant Golden House', 737, 'Rijswijk'],
#  ['DEM Restaurant', 878, 'Rijswijk'],
#  ['Barista Café Almere', 20, 'Almere Centrum Landdrostdreef'],
#  ['Restaurant Ida', 321, 'Almere Centrum Landdrostdreef'],
#  ['Tapas Barça', 251, 'Almere Centrum Landdrostdreef'],
#  ['Hudson Bar & Kitchen Almere', 437, 'Almere Centrum Landdrostdreef'],
#  ['Barakha Markt', 60, 'Almere Centrum Landdrostdreef'],
#  ['Barakha BV', 60, 'Almere Centrum Landdrostdreef'],
#  ['Thais Restaurant Mallika', 68, 'Almere Centrum Landdrostdreef'],
#  ['Le Baron', 311, 'Almere Centrum Landdrostdreef'],
#  ['Holland & Barrett', 250, 'Almere Centrum Landdrostdreef'],
#  ['Restaurant De Beren Almere', 673, 'Almere Centrum Landdrostdreef'],
#  ['Crystal Restaurant & Danscafé', 323, 'Almere Centrum Landdrostdreef'],
#  ['Restaurant La Couronne', 32, 'Almere Centrum Landdrostdreef'],
#  ['Chinees Surinaams Restaurant New Lung Ma',
#   334,
#   'Almere Centrum Landdrostdreef'],
#  ['Barbier Achie', 350, 'Almere Centrum Landdrostdreef'],
#  ['Grill-Bar Jeruzalem', 842, 'Almere Centrum Landdrostdreef'],
#  ['Farida Surinaams restaurant', 710, 'Almere Centrum Landdrostdreef'],
#  ["Reh's Barber Place", 387, 'Almere Centrum Landdrostdreef'],
#  ["Marvin's Barbershop", 405, 'Almere Centrum Landdrostdreef'],
#  ['UWV Restaurant', 431, 'Almere Centrum Landdrostdreef'],
#  ['Wallstreet Barbershop', 435, 'Almere Centrum Landdrostdreef'],
#  ['El Rey (Argentijns Restaurant)', 436, 'Almere Centrum Landdrostdreef'],
#  ['Köfte House Baran', 456, 'Almere Centrum Landdrostdreef'],
#  ['Bartiméus Almere', 472, 'Almere Centrum Landdrostdreef'],
#  ['Aryana restaurant', 553, 'Almere Centrum Landdrostdreef'],
#  ['Best Indian Restaurant', 568, 'Almere Centrum Landdrostdreef'],
#  ['No Budget Restaurant Almere gratis maaltijden aan minderbedeelden',
#   602,
#   'Almere Centrum Landdrostdreef'],
#  ['Barbershop Almere', 654, 'Almere Centrum Landdrostdreef'],
#  ['Barnyard Living BV', 747, 'Almere Centrum Landdrostdreef'],
#  ['Barbier Rogier', 829, 'Almere Centrum Landdrostdreef'],
#  ['Bar-b-Que Park', 857, 'Almere Centrum Landdrostdreef'],
#  ['Barada Restaurant Almere', 859, 'Almere Centrum Landdrostdreef'],
#  ['Chinees Restaurant BUDDHA Restaurant Lounge',
#   483,
#   'Almere Centrum Landdrostdreef'],
#  ['Maaike en Bar', 930, 'Almere Centrum Landdrostdreef'],
#  ['Sultan Pizzeria Shoarma Restaurant', 593, 'Almere Centrum Landdrostdreef'],
#  ['Logopedie Almere-Stad Barbara Stuyling de Lange',
#   696,
#   'Almere Centrum Landdrostdreef'],
#  ['Barbier van Breugel', 724, 'Almere Centrum Landdrostdreef'],
#  ['Restaurant Cucaracha La Mexican Cantina', 598, 'Zwolle'],
#  ['Restaurant W', 158, 'Zwolle'],
#  ['Het Wijnhuis | Grandcafé | Restaurant | Zwolle', 623, 'Zwolle'],
#  ['Da Nini Italiaans Restaurant', 699, 'Zwolle'],
#  ['Uno Fusion Cusine Restaurant', 674, 'Zwolle'],
#  ['Bar en brood', 698, 'Zwolle'],
#  ['Restaurant & Brasserie Dunnik', 854, 'Zwolle'],
#  ['Best Western Hotel Restaurant Fidder', 767, 'Zwolle'],
#  ['Restaurant Bistro De Buik van Parijs', 602, 'Zwolle'],
#  ...]

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
df1 = pd.DataFrame(list, columns=['Name','Distance','Station Name'])

# %%
df1
# Out:
#                                       Name  Distance Station Name
# 0                        Abby's Restaurant       862      Alkmaar
# 1                         Restaurant Stoer        97      Alkmaar
# 2     King Sing Chinees-Indisch Restaurant       211      Alkmaar
# 3                Restaurant 't Stokpaardje       819      Alkmaar
# 4              Restaurant Het Gulden Vlies       749      Alkmaar
# ...                                    ...       ...          ...
# 2729  Fong-Fou Chinees Oriental Restaurant       715       Raalte
# 2730             Tijenraan Café Restaurant       733       Raalte
# 2731                     Holland & Barrett       545       Raalte
# 2732             Boemeltje, Restaurant Het       638       Raalte
# 2733                        Bart Brentjens       872   Ravenstein
#
# [2734 rows x 3 columns]

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
dfa2 = []
for _, row in df0.iloc[:150].iterrows():
    url2 = "https://api.yelp.com/v3/businesses/search?categories=restaurants,bars,landmarks&latitude={}&longitude={}&limit=50&radius=1000&sortBy=ratings".format(df0['Latitude'][x], df0['Longitude'][x])
    
    headers2 = {
        "Authorization": "Bearer key"
    }
    response = requests.get(url2, headers=headers2)

    dfa2.append(response.json())
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# {'businesses': [{'id': 'cphfSyGCkVjKfQgQdJw9fw',
#    'alias': 'de-binnenkomer-alkmaar-2',
#    'name': 'De Binnenkomer',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jODIFLQt6XnXwjfwE9gGGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/de-binnenkomer-alkmaar-2?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 10,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 52.6329002, 'longitude': 4.7444201},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Kerkplein 6',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 KL',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Kerkplein 6', '1811 KL Alkmaar', 'The Netherlands']},
#    'phone': '+31725822655',
#    'display_phone': '+31 72 582 2655',
#    'distance': 599.4072940907039,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1100',
#        'end': '0000',
#        'day': 1},
#       {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 3},
#       {'is_overnight': True, 'start': '1100', 'end': '0100', 'day': 4},
#       {'is_overnight': True, 'start': '1100', 'end': '0100', 'day': 5},
#       {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.debinnenkomer.nl/menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'DO75ODJL2q0fYspFgh0FkQ',
#    'alias': 'vers-eten-en-drinken-alkmaar',
#    'name': 'Vers Eten & Drinken',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Nr3rUQtfwQehPKRTn6EjUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vers-eten-en-drinken-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 2,
#    'categories': [{'alias': 'diyfood', 'title': 'Do-It-Yourself Food'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 52.6370234304286,
#     'longitude': 4.73906455415129},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Stationsweg 41',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1815 CB',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Stationsweg 41',
#      '1815 CB Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725110822',
#    'display_phone': '+31 72 511 0822',
#    'distance': 77.34336015072499,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '0700',
#        'end': '2000',
#        'day': 0},
#       {'is_overnight': False, 'start': '0700', 'end': '2000', 'day': 1},
#       {'is_overnight': False, 'start': '0700', 'end': '2000', 'day': 2},
#       {'is_overnight': False, 'start': '0700', 'end': '2000', 'day': 3},
#       {'is_overnight': False, 'start': '0700', 'end': '2000', 'day': 4},
#       {'is_overnight': False, 'start': '1100', 'end': '2000', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '2000', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'ypFFYFTiLvCdCFydJ7UgmQ',
#    'alias': 'daikichi-alkmaar',
#    'name': 'Daikichi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WbCmSuZRNtH41LDtFx-o3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daikichi-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.6370583, 'longitude': 4.73982},
#    'transactions': [],
#    'location': {'address1': 'Stationsweg 58',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1815 CD',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Stationsweg 58',
#      '1815 CD Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725114422',
#    'display_phone': '+31 72 511 4422',
#    'distance': 54.04131208278735,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1700',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://daikichi.nl/menus/drtttfdxx',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'HwJrZpzapwTHmm8mZCPMvg',
#    'alias': 'burger-king-alkmaar',
#    'name': 'Burger King',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E7Xdv-lngJi4FhE9I7ZOTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burger-king-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 52.637683, 'longitude': 4.740366},
#    'transactions': [],
#    'location': {'address1': 'Stationsweg 45',
#     'address2': '',
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1815 CB',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Stationsweg 45',
#      '1815 CB Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725200932',
#    'display_phone': '+31 72 520 0932',
#    'distance': 38.753209797124605,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'vMDaqJbmS2EES9aaqkITTQ',
#    'alias': 'deli-alkmaar',
#    'name': 'Deli',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/455woPAi1RMibEtTTOv_sQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/deli-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 5,
#    'categories': [{'alias': 'indonesian', 'title': 'Indonesian'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 52.6309586, 'longitude': 4.7501798},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Mient 8',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 NC',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Mient 8', '1811 NC Alkmaar', 'The Netherlands']},
#    'phone': '+31725154082',
#    'display_phone': '+31 72 515 4082',
#    'distance': 1009.748379483375,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1700',
#        'end': '2200',
#        'day': 1},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.indonesischrestaurantdeli.nl/menukaart',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'kESPCAzgMi93lQ-uBm4sKA',
#    'alias': 'anne-en-max-alkmaar',
#    'name': 'Anne & Max',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UQwdAKmlTD9l_Q7vwlVMrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anne-en-max-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 11,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 52.6303, 'longitude': 4.74988},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Kraanbuurt 3',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1811 BK',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Kraanbuurt 3', '1811 BK Alkmaar', 'The Netherlands']},
#    'phone': '+31725205868',
#    'display_phone': '+31 72 520 5868',
#    'distance': 1050.9389047964175,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'TZ47GLh3Gmt5ImVgH8NGzg',
#    'alias': 'de-buren-alkmaar',
#    'name': 'De Buren',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XR-ttdPGyRaEDvH0xYsteA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/de-buren-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 9,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 52.6301944664123, 'longitude': 4.7498997311506},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Mient 37',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 NB',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Mient 37', '1811 NB Alkmaar', 'The Netherlands']},
#    'phone': '+31725120308',
#    'display_phone': '+31 72 512 0308',
#    'distance': 1060.7939670377473,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.restaurant-deburen.nl/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'QPS4Ffz8VO5yXVPH_cS6kw',
#    'alias': 'king-sing-alkmaar',
#    'name': 'King Sing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oBmGkULPdVaQ-K4K9ShLYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/king-sing-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 2,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 52.6358, 'longitude': 4.73852},
#    'transactions': [],
#    'location': {'address1': 'Stationweg 8',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1815 CC',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Stationweg 8', '1815 CC Alkmaar', 'The Netherlands']},
#    'phone': '+31725128825',
#    'display_phone': '+31 72 512 8825',
#    'distance': 212.2733144925375,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1600',
#        'end': '2200',
#        'day': 0},
#       {'is_overnight': False, 'start': '1700', 'end': '2030', 'day': 1},
#       {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'MoOO85fnpIpGc1GZnkTo8A',
#    'alias': 'aloha-alkmaar',
#    'name': 'Aloha',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MJaDG4V13gCjARceBISYaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aloha-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 5,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.6328392, 'longitude': 4.7498398},
#    'transactions': [],
#    'location': {'address1': 'Gedempte Nieuwe Sloot 11',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 KN',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Gedempte Nieuwe Sloot 11',
#      '1811 KN Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725119638',
#    'display_phone': '+31 72 511 9638',
#    'distance': 852.7449434363177,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.fishandchips-alkmaar.nl/foodticket/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'Kq04sqR6Xch68kF5MxVsOA',
#    'alias': 'stadsstrand-de-kade-alkmaar',
#    'name': 'Stadsstrand de Kade',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/liTpSV-BFU6EtcL5rC8YvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stadsstrand-de-kade-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 3,
#    'categories': [{'alias': 'beachbars', 'title': 'Beach Bars'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'beaches', 'title': 'Beaches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.635178, 'longitude': 4.748191},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Noorderkade',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1823 CJ',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Noorderkade', '1823 CJ Alkmaar', 'The Netherlands']},
#    'phone': '+31619687542',
#    'display_phone': '+31 6 19687542',
#    'distance': 620.6513341917654,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'S9GIKSLRb_DAM0JEt023XQ',
#    'alias': 'alkmaars-koffiehuis-alkmaar',
#    'name': 'Alkmaars Koffiehuis',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OFwaIoyO6LJb4l31rK4-mA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alkmaars-koffiehuis-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.6325450184915,
#     'longitude': 4.74674988538027},
#    'transactions': [],
#    'location': {'address1': 'Gedempte Nieuwesloot 42',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 KT',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Gedempte Nieuwesloot 42',
#      '1811 KT Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725318712',
#    'display_phone': '+31 72 531 8712',
#    'distance': 723.9196172713763,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '0000',
#        'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '0000', 'day': 3},
#       {'is_overnight': True, 'start': '1200', 'end': '0200', 'day': 4},
#       {'is_overnight': True, 'start': '1000', 'end': '0200', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '1900', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'PzE-C-f3afe3Wp2k_4PImQ',
#    'alias': 'the-hielander-alkmaar',
#    'name': 'Schots Restaurant Hielander',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lMnzTyg6QSL_geqYKNhqTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hielander-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 5,
#    'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 52.6296341, 'longitude': 4.7472053},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Ridderstraat 15',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1811 EX',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Ridderstraat 15',
#      '1811 EX Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725120015',
#    'display_phone': '+31 72 512 0015',
#    'distance': 1008.5839781538273,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.schotsrestauranthielander.nl/menu.htm',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'Th4fT_Ydv_X5w0W9HH7uLA',
#    'alias': 'saladebar-oogst-alkmaar',
#    'name': 'Saladebar Oogst',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MMtiTjsv37sPSXqxZfzSeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saladebar-oogst-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.63347, 'longitude': 4.74259},
#    'transactions': [],
#    'location': {'address1': 'Zevenhuizen 8',
#     'address2': None,
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 KB',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Zevenhuizen 8',
#      '1811 KB Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725823171',
#    'display_phone': '+31 72 582 3171',
#    'distance': 479.2986157354422,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1100',
#        'end': '1930',
#        'day': 0},
#       {'is_overnight': False, 'start': '1100', 'end': '1930', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '1930', 'day': 3},
#       {'is_overnight': False, 'start': '1100', 'end': '1930', 'day': 4},
#       {'is_overnight': False, 'start': '1100', 'end': '1930', 'day': 5},
#       {'is_overnight': False, 'start': '1000', 'end': '1930', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://saladebaroogst.nl/menukaart/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'zIBd4SxwE_kXtEym1SzPgQ',
#    'alias': 'irish-pub-gunnerys-alkmaar',
#    'name': "Irish Pub Gunnery's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jt7szldmpfdHHUdGBBzRVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/irish-pub-gunnerys-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 3,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.62979, 'longitude': 4.75007},
#    'transactions': [],
#    'location': {'address1': 'Verdronkenoord 123-A',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1811 BD',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Verdronkenoord 123-A',
#      '1811 BD Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725209148',
#    'display_phone': '+31 72 520 9148',
#    'distance': 1101.3625315377635,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '7q9pfi_RK6HdNx4IaUaUPA',
#    'alias': 'mojos-alkmaar',
#    'name': "Mojo's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BOvIQBjyo-7iJT37CWCu_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mojos-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 2,
#    'categories': [{'alias': 'danceclubs', 'title': 'Dance Clubs'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.631796905586, 'longitude': 4.75012692632264},
#    'transactions': [],
#    'location': {'address1': 'Houttil 18',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 JM',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Houttil 18', '1811 JM Alkmaar', 'The Netherlands']},
#    'phone': '+31725207608',
#    'display_phone': '+31 72 520 7608',
#    'distance': 942.0027393749233,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1000',
#        'end': '0000',
#        'day': 0},
#       {'is_overnight': False, 'start': '1000', 'end': '0000', 'day': 1},
#       {'is_overnight': True, 'start': '1000', 'end': '0200', 'day': 2},
#       {'is_overnight': True, 'start': '1000', 'end': '0200', 'day': 3},
#       {'is_overnight': True, 'start': '1000', 'end': '0300', 'day': 4},
#       {'is_overnight': True, 'start': '1000', 'end': '0300', 'day': 5},
#       {'is_overnight': True, 'start': '1000', 'end': '0200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '6lLEl2HsnwBsv-yQ_WMbPw',
#    'alias': 'het-grand-cafeetje-alkmaar',
#    'name': 'Het Grand Cafeetje',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yuPQsmPdWCWy8A0tWXOT8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/het-grand-cafeetje-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.6324005, 'longitude': 4.7508101},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Peperstraat 1',
#     'address2': None,
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 LX',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Peperstraat 1',
#      '1811 LX Alkmaar',
#      'The Netherlands']},
#    'phone': '+31727501834',
#    'display_phone': '+31 72 750 1834',
#    'distance': 935.7281656931732,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '2200',
#        'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.grandcafeetje.nl/Het_Grand_Cafeetje/Menu.html',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '7Z11XD-NiG0cxCXjK_ccnA',
#    'alias': 'horecacentrum-de-studio-alkmaar',
#    'name': 'Horecacentrum De Studio',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/horecacentrum-de-studio-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.6336, 'longitude': 4.74393},
#    'transactions': [],
#    'location': {'address1': 'Canadaplein 2',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1811 KE',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Canadaplein 2',
#      '1811 KE Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725489897',
#    'display_phone': '+31 72 548 9897',
#    'distance': 516.498093746401,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.grandcafedestudio.nl/DeStudioMenu.html',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'kEvq5ha0WbI37OuQ9nP8vg',
#    'alias': 'vito-alkmaar',
#    'name': 'Vito',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ktZwgqii2Dy6LUM7NhQWvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vito-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 52.627774, 'longitude': 4.754895},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Turfmarkt 1-9',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1813 SC',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Turfmarkt 1-9',
#      '1813 SC Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725113178',
#    'display_phone': '+31 72 511 3178',
#    'distance': 1485.8453538466451,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.restaurant-vito.nl/menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'IcUQtllmGPenP6kLV_R0VA',
#    'alias': 'abbys-alkmaar',
#    'name': "Abby's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NNjkiZdvE15_V-DidFllXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abbys-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 7,
#    'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 52.6301344, 'longitude': 4.7424737},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Ritsevoort 60',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1811 DP',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Ritsevoort 60',
#      '1811 DP Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725111111',
#    'display_phone': '+31 72 511 1111',
#    'distance': 852.017140325663,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '75RhjIjSLws-wTvooo5MRA',
#    'alias': 'proeflokaal-bregje-alkmaar',
#    'name': 'Proeflokaal Bregje',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VD6f3ka488bUFmBJq2hiSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/proeflokaal-bregje-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 4,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 2.3,
#    'coordinates': {'latitude': 52.634306, 'longitude': 4.745538},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Paardenmarkt 4',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 KH',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Paardenmarkt 4',
#      '1811 KH Alkmaar',
#      'The Netherlands']},
#    'phone': '+31723030402',
#    'display_phone': '+31 72 303 0402',
#    'distance': 525.2107427451322,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.proeflokaalbregje.nl/menukaart',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'CMhYQStnZEv_YgXaGE1fEA',
#    'alias': 'restaurant-zegels-alkmaar',
#    'name': 'restaurant zegels',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-zegels-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 3,
#    'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 52.632431, 'longitude': 4.7470102},
#    'transactions': [],
#    'location': {'address1': 'Gedempte Nieuwesloot 36',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 KT',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Gedempte Nieuwesloot 36',
#      '1811 KT Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725760970',
#    'display_phone': '+31 72 576 0970',
#    'distance': 744.6440355872974,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.restaurantzegels.nl/menukaart-restaurant-zegels.php',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'LmLkPaumrV_BGK7mXYq75g',
#    'alias': 'meat-en-co-alkmaar',
#    'name': 'Meat & Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BvnRTnP6wLFOVdaBvqEz1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meat-en-co-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 6,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 52.63068, 'longitude': 4.74988},
#    'transactions': [],
#    'location': {'address1': 'Mient 22',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 NC',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Mient 22', '1811 NC Alkmaar', 'The Netherlands']},
#    'phone': '+31725823307',
#    'display_phone': '+31 72 582 3307',
#    'distance': 1020.6355087576528,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1130',
#        'end': '2200',
#        'day': 0},
#       {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 1},
#       {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '3c6Tcupn0gn9688v0ghd3Q',
#    'alias': 'fresh-food-alkmaar',
#    'name': 'Fresh Food',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-food-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 0,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 0.0,
#    'coordinates': {'latitude': 52.63775, 'longitude': 4.74094},
#    'transactions': [],
#    'location': {'address1': 'Stationsweg 47a',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1815 CB',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Stationsweg 47a',
#      '1815 CB Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725150901',
#    'display_phone': '+31 72 515 0901',
#    'distance': 93.87041630226362,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '4rzABYX4AdsGoG3UbTzlVQ',
#    'alias': 'petershoek-café-alkmaar',
#    'name': 'Petershoek Café',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petershoek-caf%C3%A9-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 0,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 0.0,
#    'coordinates': {'latitude': 52.6374, 'longitude': 4.74121},
#    'transactions': [],
#    'location': {'address1': 'Spoorstraat 92',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1815 BM',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Spoorstraat 92',
#      '1815 BM Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725121097',
#    'display_phone': '+31 72 512 1097',
#    'distance': 90.49918999393957,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '9rmihaTOj3f2_0Jm5cRr2Q',
#    'alias': 'burgers-en-zo-alkmaar',
#    'name': 'Burgers & Zo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mN7guE-55DyMg1_7xPmXRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burgers-en-zo-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafeteria', 'title': 'Cafeteria'},
#     {'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 52.6338354, 'longitude': 4.745621},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Paardenmarkt 5',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 KH',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Paardenmarkt 5',
#      '1811 KH Alkmaar',
#      'The Netherlands']},
#    'phone': '+31727370219',
#    'display_phone': '+31 72 737 0219',
#    'distance': 566.070511391871,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1100',
#        'end': '2100',
#        'day': 1},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 3},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 4},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '2100', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.burgersenzo.nl/index.php/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'MhGKIaXXK_giaQPVGTA76g',
#    'alias': 'pizzeria-ristorante-la-famiglia-alkmaar',
#    'name': 'Pizzeria Ristorante La Famiglia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ev_gshmrudiOTzpjNN-7Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzeria-ristorante-la-famiglia-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.6333, 'longitude': 4.7424},
#    'transactions': [],
#    'location': {'address1': 'Zevenhuizen 5',
#     'address2': '',
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1811 KB',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Zevenhuizen 5',
#      '1811 KB Alkmaar',
#      'The Netherlands']},
#    'phone': '+31727501872',
#    'display_phone': '+31 72 750 1872',
#    'distance': 499.8180731679537,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1630',
#        'end': '2200',
#        'day': 0},
#       {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://pizzerialafamiglia.nl/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'w96V31GKQlHF8QZchbkdyw',
#    'alias': 'heeren-van-sonoy-alkmaar',
#    'name': 'Heeren van Sonoy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gXho2QO6QCuaxCJ7KkYm2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heeren-van-sonoy-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 7,
#    'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 52.6320609304149,
#     'longitude': 4.74781882944625},
#    'transactions': [],
#    'location': {'address1': 'Hof van sonoy 1',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 KR',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Hof van sonoy 1',
#      '1811 KR Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725121222',
#    'display_phone': '+31 72 512 1222',
#    'distance': 811.7969541676354,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1000',
#        'end': '0000',
#        'day': 0},
#       {'is_overnight': False, 'start': '1000', 'end': '0000', 'day': 1},
#       {'is_overnight': False, 'start': '1000', 'end': '0000', 'day': 2},
#       {'is_overnight': False, 'start': '1000', 'end': '0000', 'day': 3},
#       {'is_overnight': False, 'start': '1000', 'end': '0000', 'day': 4},
#       {'is_overnight': False, 'start': '1000', 'end': '0000', 'day': 5},
#       {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'jzpMVfU4rgyVAIiESA53Bw',
#    'alias': 'gulden-vlies-alkmaar',
#    'name': 'Gulden Vlies',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nxQqq9z_-oj_hj0dZJ0q8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gulden-vlies-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.63114, 'longitude': 4.74339},
#    'transactions': [],
#    'location': {'address1': 'Koorstraat 30',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1811 GP',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Koorstraat 30',
#      '1811 GP Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725122442',
#    'display_phone': '+31 72 512 2442',
#    'distance': 749.6198242086455,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '0930',
#        'end': '0200',
#        'day': 0},
#       {'is_overnight': True, 'start': '0930', 'end': '0200', 'day': 1},
#       {'is_overnight': True, 'start': '0930', 'end': '0200', 'day': 2},
#       {'is_overnight': True, 'start': '0930', 'end': '0200', 'day': 3},
#       {'is_overnight': True, 'start': '0930', 'end': '0200', 'day': 4},
#       {'is_overnight': True, 'start': '0930', 'end': '0200', 'day': 5},
#       {'is_overnight': True, 'start': '1100', 'end': '0200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '1hvgb2yuU_pgCPaiTaq3DQ',
#    'alias': 'la-cubanita-alkmaar-alkmaar-2',
#    'name': 'La Cubanita Alkmaar',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-cubanita-alkmaar-alkmaar-2?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.6307, 'longitude': 4.74992},
#    'transactions': [],
#    'location': {'address1': 'Verdronkenoord 102',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1811 BH',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Verdronkenoord 102',
#      '1811 BH Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725200019',
#    'display_phone': '+31 72 520 0019',
#    'distance': 1019.1139257354848,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1700',
#        'end': '2200',
#        'day': 0},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 1},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '-U53NypY5blVk5HV-T1wtg',
#    'alias': 'superthai-restaurant-alkmaar',
#    'name': 'SuperThai Restaurant ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hlKf5W8lMtbc1hiNuIjoHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/superthai-restaurant-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 3,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.3,
#    'coordinates': {'latitude': 52.632321, 'longitude': 4.746901300000001},
#    'transactions': [],
#    'location': {'address1': 'Gedempte Nieuwesloot 115A',
#     'address2': None,
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 KR',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Gedempte Nieuwesloot 115A',
#      '1811 KR Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725318563',
#    'display_phone': '+31 72 531 8563',
#    'distance': 749.6106910535735,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1600',
#        'end': '2200',
#        'day': 0},
#       {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 1},
#       {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.superthais.nl',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '-8lEsMTfYhSFMg8_kPe6ww',
#    'alias': 'café-bar-odeon-alkmaar',
#    'name': 'Café-Bar Odeon',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-bar-odeon-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'poolhalls', 'title': 'Pool Halls'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.6301994, 'longitude': 4.7511501},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Hekelstraat 19',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 BL',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Hekelstraat 19',
#      '1811 BL Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725116542',
#    'display_phone': '+31 72 511 6542',
#    'distance': 1117.6786219087742,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '1500',
#        'end': '0200',
#        'day': 0},
#       {'is_overnight': True, 'start': '1500', 'end': '0200', 'day': 1},
#       {'is_overnight': True, 'start': '1500', 'end': '0200', 'day': 2},
#       {'is_overnight': True, 'start': '1500', 'end': '0200', 'day': 3},
#       {'is_overnight': True, 'start': '1500', 'end': '0200', 'day': 4},
# ...
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/de-amstelhoek-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.6321, 'longitude': 4.75106},
#    'transactions': [],
#    'location': {'address1': 'Voordam 1',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1811 MA',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Voordam 1', '1811 MA Alkmaar', 'The Netherlands']},
#    'phone': '+31725121303',
#    'display_phone': '+31 72 512 1303',
#    'distance': 967.9020076874574,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'zglm4q8SLzkntGAccgz1gw',
#    'alias': 'il-colosseo-alkmaar',
#    'name': 'Il Colosseo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xiIdkXgOisCRTsR-KZdXMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-colosseo-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.63168, 'longitude': 4.74495},
#    'transactions': [],
#    'location': {'address1': 'Schoutenstraat 12',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1811 HD',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Schoutenstraat 12',
#      '1811 HD Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725202223',
#    'display_phone': '+31 72 520 2223',
#    'distance': 738.3859911669595,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1700',
#        'end': '2200',
#        'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.ilcolosseo.nl/?si=9',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'llccr8W3gJKqpUm2SJyjJw',
#    'alias': 'rue-de-la-plume-alkmaar',
#    'name': 'Rue de la Plume',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rue-de-la-plume-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.63245, 'longitude': 4.74799},
#    'transactions': [],
#    'location': {'address1': 'Veerstraat 22',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1811 LB',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Veerstraat 22',
#      '1811 LB Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725201212',
#    'display_phone': '+31 72 520 1212',
#    'distance': 789.023446360917,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1800',
#        'end': '0000',
#        'day': 0},
#       {'is_overnight': False, 'start': '1800', 'end': '0000', 'day': 3},
#       {'is_overnight': False, 'start': '1800', 'end': '0000', 'day': 4},
#       {'is_overnight': False, 'start': '1800', 'end': '0000', 'day': 5},
#       {'is_overnight': False, 'start': '1800', 'end': '0000', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.ruedelaplume.nl/index.php?category=homepage&id=35',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'dy6wUpjzXJN-x9tgq-Il1g',
#    'alias': 't-friethuys-alkmaar',
#    'name': "'t Friethuys",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jVLYmiI85YgHvoLpg6HG1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/t-friethuys-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 2,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.6314507, 'longitude': 4.7495699},
#    'transactions': [],
#    'location': {'address1': 'Magdalenenstraat 4',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 JR',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Magdalenenstraat 4',
#      '1811 JR Alkmaar',
#      'The Netherlands']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 937.8352468571736,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1130',
#        'end': '1900',
#        'day': 1},
#       {'is_overnight': False, 'start': '1130', 'end': '1900', 'day': 2},
#       {'is_overnight': False, 'start': '1130', 'end': '2100', 'day': 3},
#       {'is_overnight': False, 'start': '1130', 'end': '1900', 'day': 4},
#       {'is_overnight': False, 'start': '1130', 'end': '1900', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '1900', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'XinGareOR_-LGglC3zKoLA',
#    'alias': 'taormina-alkmaar-2',
#    'name': 'Taormina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/asIGt5Ljtb0S1YfZqVKsPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taormina-alkmaar-2?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.6292915, 'longitude': 4.75001},
#    'transactions': [],
#    'location': {'address1': 'Laat 85-87',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 EC',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Laat 85-87', '1811 EC Alkmaar', 'The Netherlands']},
#    'phone': '+31725110364',
#    'display_phone': '+31 72 511 0364',
#    'distance': 1149.6070313784464,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1700',
#        'end': '2200',
#        'day': 0},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 1},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.taormina.nl/menukaart/pizza/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '0lMnsFrdxUlWA56tazhhcw',
#    'alias': 'ristobar-italica-alkmaar',
#    'name': 'Ristobar Italica',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0E0-_PbjtPKpwYQl20ISMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ristobar-italica-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 5,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 2.4,
#    'coordinates': {'latitude': 52.6296641992219,
#     'longitude': 4.74931573380744},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Laat 117',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 ED',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Laat 117', '1811 ED Alkmaar', 'The Netherlands']},
#    'phone': '+31725113135',
#    'display_phone': '+31 72 511 3135',
#    'distance': 1083.0744620729238,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1700',
#        'end': '2200',
#        'day': 1},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '1530', 'day': 5},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1800', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'dPQfDGW1aSTCf5M24Qj_jQ',
#    'alias': 'le-bon-alkmaar',
#    'name': 'Le Bon',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jqi14qKF-e3UFOB94qzZgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-bon-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 52.6296005, 'longitude': 4.7471299},
#    'transactions': [],
#    'location': {'address1': 'Ridderstraat 17',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 EX',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Ridderstraat 17',
#      '1811 EX Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725122879',
#    'display_phone': '+31 72 512 2879',
#    'distance': 1008.7088239418918,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1730',
#        'end': '0000',
#        'day': 2},
#       {'is_overnight': False, 'start': '1730', 'end': '0000', 'day': 3},
#       {'is_overnight': False, 'start': '1730', 'end': '0000', 'day': 4},
#       {'is_overnight': False, 'start': '1730', 'end': '0000', 'day': 5},
#       {'is_overnight': False, 'start': '1730', 'end': '0000', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://restaurantlebon.nl/?/soepen',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'mgyRzcDamnV3vkg0U48N5A',
#    'alias': 'de-bonte-bengel-alkmaar',
#    'name': 'De Bonte Bengel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lQI3-cjBCXd2dpypgwvA4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/de-bonte-bengel-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 2.8,
#    'coordinates': {'latitude': 52.63320091396, 'longitude': 4.74450283813587},
#    'transactions': [],
#    'location': {'address1': 'Kerkplein 3-4',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 KL',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Kerkplein 3-4',
#      '1811 KL Alkmaar',
#      'The Netherlands']},
#    'phone': '+31725111713',
#    'display_phone': '+31 72 511 1713',
#    'distance': 574.7221520255662,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1000',
#        'end': '2200',
#        'day': 0},
#       {'is_overnight': False, 'start': '1000', 'end': '2200', 'day': 1},
#       {'is_overnight': False, 'start': '1000', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1000', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1000', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1000', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1000', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.bontebengel.nl/home/9',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'MJEEnKY7_rOQMstYDOEE6w',
#    'alias': 'subway-alkmaar',
#    'name': 'Subway',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/emP-Gt5RmOfnh3hFxFmAIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/subway-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 1,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 52.63069, 'longitude': 4.74586},
#    'transactions': [],
#    'location': {'address1': 'Laat 199',
#     'address2': None,
#     'address3': None,
#     'city': 'Alkmaar',
#     'zip_code': '1811 EG',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Laat 199', '1811 EG Alkmaar', 'The Netherlands']},
#    'phone': '+31725207333',
#    'display_phone': '+31 72 520 7333',
#    'distance': 861.8243738210845,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1130',
#        'end': '1800',
#        'day': 0},
#       {'is_overnight': False, 'start': '1000', 'end': '1800', 'day': 1},
#       {'is_overnight': False, 'start': '1000', 'end': '1800', 'day': 2},
#       {'is_overnight': False, 'start': '1000', 'end': '2100', 'day': 3},
#       {'is_overnight': False, 'start': '1000', 'end': '1800', 'day': 4},
#       {'is_overnight': False, 'start': '1000', 'end': '1800', 'day': 5},
#       {'is_overnight': False, 'start': '1130', 'end': '1800', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.subway.com/nl-NL/MenuNutrition',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'uiuZ66L-79J_qjuadRoi8g',
#    'alias': 'cafe-bali-alkmaar',
#    'name': 'Cafe Bali',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mkjYkBULCwmFCSKD26q0Sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-bali-alkmaar?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#    'review_count': 3,
#    'categories': [{'alias': 'indonesian', 'title': 'Indonesian'}],
#    'rating': 3.7,
#    'coordinates': {'latitude': 52.6323184, 'longitude': 4.7504447},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Houttil 8',
#     'address2': '',
#     'address3': '',
#     'city': 'Alkmaar',
#     'zip_code': '1811 JM',
#     'country': 'NL',
#     'state': 'NH',
#     'display_address': ['Houttil 8', '1811 JM Alkmaar', 'The Netherlands']},
#    'phone': '+31722202209',
#    'display_phone': '+31 72 220 2209',
#    'distance': 920.3244724023469,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1700',
#        'end': '2200',
#        'day': 2},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}}],
#  'total': 92,
#  'region': {'center': {'longitude': 4.73985, 'latitude': 52.63753}}}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
dfa2[0]['businesses'][0]
# Out:
# {'id': 'cphfSyGCkVjKfQgQdJw9fw',
#  'alias': 'de-binnenkomer-alkmaar-2',
#  'name': 'De Binnenkomer',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jODIFLQt6XnXwjfwE9gGGA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/de-binnenkomer-alkmaar-2?adjust_creative=qPSsPz72IcnSS_azKnlktQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qPSsPz72IcnSS_azKnlktQ',
#  'review_count': 10,
#  'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#   {'alias': 'diners', 'title': 'Diners'}],
#  'rating': 4.7,
#  'coordinates': {'latitude': 52.6329002, 'longitude': 4.7444201},
#  'transactions': [],
#  'price': '€€',
#  'location': {'address1': 'Kerkplein 6',
#   'address2': '',
#   'address3': '',
#   'city': 'Alkmaar',
#   'zip_code': '1811 KL',
#   'country': 'NL',
#   'state': 'NH',
#   'display_address': ['Kerkplein 6', '1811 KL Alkmaar', 'The Netherlands']},
#  'phone': '+31725822655',
#  'display_phone': '+31 72 582 2655',
#  'distance': 599.4072940907039,
#  'business_hours': [{'open': [{'is_overnight': False,
#      'start': '1100',
#      'end': '0000',
#      'day': 1},
#     {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 2},
#     {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 3},
#     {'is_overnight': True, 'start': '1100', 'end': '0100', 'day': 4},
#     {'is_overnight': True, 'start': '1100', 'end': '0100', 'day': 5},
#     {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 6}],
#    'hours_type': 'REGULAR',
#    'is_open_now': False}],
#  'attributes': {'business_temp_closed': None,
#   'menu_url': 'http://www.debinnenkomer.nl/menu',
#   'open24_hours': None,
#   'waitlist_reservation': None}}

# %%
list = []
statNameList = df0['Name'][:150]
nameIndex = -1
for item in dfa2:
    nameIndex += 1
    for loca in item['businesses']:
        sl = []
        sl.append(loca['name'])
        sl.append(loca['distance'])
        sl.append(loca['rating'])
        sl.append(loca['review_count'])
        sl.append(loca['price'])
        sl.append(statNameList[nameIndex])
        list.append(sl)
# Out:
# [['De Binnenkomer', 599.4072940907039, 4.7, 'Alkmaar'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Alkmaar'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Alkmaar'],
#  ['Burger King', 38.753209797124605, 3.0, 'Alkmaar'],
#  ['Deli', 1009.748379483375, 4.8, 'Alkmaar'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Alkmaar'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Alkmaar'],
#  ['King Sing', 212.2733144925375, 3.0, 'Alkmaar'],
#  ['Aloha', 852.7449434363177, 4.0, 'Alkmaar'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Alkmaar'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Alkmaar'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Alkmaar'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Alkmaar'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Alkmaar'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Alkmaar'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Alkmaar'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Alkmaar'],
#  ['Vito', 1485.8453538466451, 4.3, 'Alkmaar'],
#  ["Abby's", 852.017140325663, 4.3, 'Alkmaar'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Alkmaar'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Alkmaar'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Alkmaar'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Alkmaar'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Alkmaar'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Alkmaar'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Alkmaar'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Alkmaar'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Alkmaar'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Alkmaar'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Alkmaar'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Alkmaar'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Alkmaar'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Alkmaar'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Alkmaar'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Alkmaar'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Alkmaar'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Alkmaar'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Alkmaar'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Alkmaar'],
#  ['Moeke', 484.4824365505958, 0.0, 'Alkmaar'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Alkmaar'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Alkmaar'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Alkmaar'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Alkmaar'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Alkmaar'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Alkmaar'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Alkmaar'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Alkmaar'],
#  ['Subway', 861.8243738210845, 5.0, 'Alkmaar'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Alkmaar'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Amsterdam Noord'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Amsterdam Noord'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Amsterdam Noord'],
#  ['Burger King', 38.753209797124605, 3.0, 'Amsterdam Noord'],
#  ['Deli', 1009.748379483375, 4.8, 'Amsterdam Noord'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Amsterdam Noord'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Amsterdam Noord'],
#  ['King Sing', 212.2733144925375, 3.0, 'Amsterdam Noord'],
#  ['Aloha', 852.7449434363177, 4.0, 'Amsterdam Noord'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Amsterdam Noord'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Amsterdam Noord'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Amsterdam Noord'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Amsterdam Noord'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Amsterdam Noord'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Amsterdam Noord'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Amsterdam Noord'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Amsterdam Noord'],
#  ['Vito', 1485.8453538466451, 4.3, 'Amsterdam Noord'],
#  ["Abby's", 852.017140325663, 4.3, 'Amsterdam Noord'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Amsterdam Noord'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Amsterdam Noord'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Amsterdam Noord'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Amsterdam Noord'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Amsterdam Noord'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Amsterdam Noord'],
#  ['Pizzeria Ristorante La Famiglia',
#   499.8180731679537,
#   4.0,
#   'Amsterdam Noord'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Amsterdam Noord'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Amsterdam Noord'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Amsterdam Noord'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Amsterdam Noord'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Amsterdam Noord'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Amsterdam Noord'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Amsterdam Noord'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Amsterdam Noord'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Amsterdam Noord'],
#  ['Granada Grand Cafe & Restaurant',
#   597.1834813755764,
#   5.0,
#   'Amsterdam Noord'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Amsterdam Noord'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Amsterdam Noord'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Amsterdam Noord'],
#  ['Moeke', 484.4824365505958, 0.0, 'Amsterdam Noord'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Amsterdam Noord'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Amsterdam Noord'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Amsterdam Noord'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Amsterdam Noord'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Amsterdam Noord'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Amsterdam Noord'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Amsterdam Noord'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Amsterdam Noord'],
#  ['Subway', 861.8243738210845, 5.0, 'Amsterdam Noord'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Amsterdam Noord'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Hoogeveen'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Hoogeveen'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Hoogeveen'],
#  ['Burger King', 38.753209797124605, 3.0, 'Hoogeveen'],
#  ['Deli', 1009.748379483375, 4.8, 'Hoogeveen'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Hoogeveen'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Hoogeveen'],
#  ['King Sing', 212.2733144925375, 3.0, 'Hoogeveen'],
#  ['Aloha', 852.7449434363177, 4.0, 'Hoogeveen'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Hoogeveen'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Hoogeveen'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Hoogeveen'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Hoogeveen'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Hoogeveen'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Hoogeveen'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Hoogeveen'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Hoogeveen'],
#  ['Vito', 1485.8453538466451, 4.3, 'Hoogeveen'],
#  ["Abby's", 852.017140325663, 4.3, 'Hoogeveen'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Hoogeveen'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Hoogeveen'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Hoogeveen'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Hoogeveen'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Hoogeveen'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Hoogeveen'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Hoogeveen'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Hoogeveen'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Hoogeveen'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Hoogeveen'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Hoogeveen'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Hoogeveen'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Hoogeveen'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Hoogeveen'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Hoogeveen'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Hoogeveen'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Hoogeveen'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Hoogeveen'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Hoogeveen'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Hoogeveen'],
#  ['Moeke', 484.4824365505958, 0.0, 'Hoogeveen'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Hoogeveen'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Hoogeveen'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Hoogeveen'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Hoogeveen'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Hoogeveen'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Hoogeveen'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Hoogeveen'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Hoogeveen'],
#  ['Subway', 861.8243738210845, 5.0, 'Hoogeveen'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Hoogeveen'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Zoetermeer Driemanspolder'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Zoetermeer Driemanspolder'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Zoetermeer Driemanspolder'],
#  ['Burger King', 38.753209797124605, 3.0, 'Zoetermeer Driemanspolder'],
#  ['Deli', 1009.748379483375, 4.8, 'Zoetermeer Driemanspolder'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Zoetermeer Driemanspolder'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Zoetermeer Driemanspolder'],
#  ['King Sing', 212.2733144925375, 3.0, 'Zoetermeer Driemanspolder'],
#  ['Aloha', 852.7449434363177, 4.0, 'Zoetermeer Driemanspolder'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Zoetermeer Driemanspolder'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Zoetermeer Driemanspolder'],
#  ['Schots Restaurant Hielander',
#   1008.5839781538273,
#   3.8,
#   'Zoetermeer Driemanspolder'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Zoetermeer Driemanspolder'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Zoetermeer Driemanspolder'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Zoetermeer Driemanspolder'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Zoetermeer Driemanspolder'],
#  ['Horecacentrum De Studio',
#   516.498093746401,
#   5.0,
#   'Zoetermeer Driemanspolder'],
#  ['Vito', 1485.8453538466451, 4.3, 'Zoetermeer Driemanspolder'],
#  ["Abby's", 852.017140325663, 4.3, 'Zoetermeer Driemanspolder'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Zoetermeer Driemanspolder'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Zoetermeer Driemanspolder'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Zoetermeer Driemanspolder'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Zoetermeer Driemanspolder'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Zoetermeer Driemanspolder'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Zoetermeer Driemanspolder'],
#  ['Pizzeria Ristorante La Famiglia',
#   499.8180731679537,
#   4.0,
#   'Zoetermeer Driemanspolder'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Zoetermeer Driemanspolder'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Zoetermeer Driemanspolder'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Zoetermeer Driemanspolder'],
#  ['SuperThai Restaurant ',
#   749.6106910535735,
#   3.3,
#   'Zoetermeer Driemanspolder'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Zoetermeer Driemanspolder'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Zoetermeer Driemanspolder'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Zoetermeer Driemanspolder'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Zoetermeer Driemanspolder'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Zoetermeer Driemanspolder'],
#  ['Granada Grand Cafe & Restaurant',
#   597.1834813755764,
#   5.0,
#   'Zoetermeer Driemanspolder'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Zoetermeer Driemanspolder'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Zoetermeer Driemanspolder'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Zoetermeer Driemanspolder'],
#  ['Moeke', 484.4824365505958, 0.0, 'Zoetermeer Driemanspolder'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Zoetermeer Driemanspolder'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Zoetermeer Driemanspolder'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Zoetermeer Driemanspolder'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Zoetermeer Driemanspolder'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Zoetermeer Driemanspolder'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Zoetermeer Driemanspolder'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Zoetermeer Driemanspolder'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Zoetermeer Driemanspolder'],
#  ['Subway', 861.8243738210845, 5.0, 'Zoetermeer Driemanspolder'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Zoetermeer Driemanspolder'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Veenendaal Centrum'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Veenendaal Centrum'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Veenendaal Centrum'],
#  ['Burger King', 38.753209797124605, 3.0, 'Veenendaal Centrum'],
#  ['Deli', 1009.748379483375, 4.8, 'Veenendaal Centrum'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Veenendaal Centrum'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Veenendaal Centrum'],
#  ['King Sing', 212.2733144925375, 3.0, 'Veenendaal Centrum'],
#  ['Aloha', 852.7449434363177, 4.0, 'Veenendaal Centrum'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Veenendaal Centrum'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Veenendaal Centrum'],
#  ['Schots Restaurant Hielander',
#   1008.5839781538273,
#   3.8,
#   'Veenendaal Centrum'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Veenendaal Centrum'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Veenendaal Centrum'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Veenendaal Centrum'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Veenendaal Centrum'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Veenendaal Centrum'],
#  ['Vito', 1485.8453538466451, 4.3, 'Veenendaal Centrum'],
#  ["Abby's", 852.017140325663, 4.3, 'Veenendaal Centrum'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Veenendaal Centrum'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Veenendaal Centrum'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Veenendaal Centrum'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Veenendaal Centrum'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Veenendaal Centrum'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Veenendaal Centrum'],
#  ['Pizzeria Ristorante La Famiglia',
#   499.8180731679537,
#   4.0,
#   'Veenendaal Centrum'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Veenendaal Centrum'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Veenendaal Centrum'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Veenendaal Centrum'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Veenendaal Centrum'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Veenendaal Centrum'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Veenendaal Centrum'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Veenendaal Centrum'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Veenendaal Centrum'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Veenendaal Centrum'],
#  ['Granada Grand Cafe & Restaurant',
#   597.1834813755764,
#   5.0,
#   'Veenendaal Centrum'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Veenendaal Centrum'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Veenendaal Centrum'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Veenendaal Centrum'],
#  ['Moeke', 484.4824365505958, 0.0, 'Veenendaal Centrum'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Veenendaal Centrum'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Veenendaal Centrum'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Veenendaal Centrum'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Veenendaal Centrum'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Veenendaal Centrum'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Veenendaal Centrum'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Veenendaal Centrum'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Veenendaal Centrum'],
#  ['Subway', 861.8243738210845, 5.0, 'Veenendaal Centrum'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Veenendaal Centrum'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Sneek'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Sneek'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Sneek'],
#  ['Burger King', 38.753209797124605, 3.0, 'Sneek'],
#  ['Deli', 1009.748379483375, 4.8, 'Sneek'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Sneek'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Sneek'],
#  ['King Sing', 212.2733144925375, 3.0, 'Sneek'],
#  ['Aloha', 852.7449434363177, 4.0, 'Sneek'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Sneek'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Sneek'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Sneek'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Sneek'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Sneek'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Sneek'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Sneek'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Sneek'],
#  ['Vito', 1485.8453538466451, 4.3, 'Sneek'],
#  ["Abby's", 852.017140325663, 4.3, 'Sneek'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Sneek'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Sneek'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Sneek'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Sneek'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Sneek'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Sneek'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Sneek'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Sneek'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Sneek'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Sneek'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Sneek'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Sneek'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Sneek'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Sneek'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Sneek'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Sneek'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Sneek'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Sneek'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Sneek'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Sneek'],
#  ['Moeke', 484.4824365505958, 0.0, 'Sneek'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Sneek'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Sneek'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Sneek'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Sneek'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Sneek'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Sneek'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Sneek'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Sneek'],
#  ['Subway', 861.8243738210845, 5.0, 'Sneek'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Sneek'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Voorburg'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Voorburg'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Voorburg'],
#  ['Burger King', 38.753209797124605, 3.0, 'Voorburg'],
#  ['Deli', 1009.748379483375, 4.8, 'Voorburg'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Voorburg'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Voorburg'],
#  ['King Sing', 212.2733144925375, 3.0, 'Voorburg'],
#  ['Aloha', 852.7449434363177, 4.0, 'Voorburg'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Voorburg'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Voorburg'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Voorburg'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Voorburg'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Voorburg'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Voorburg'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Voorburg'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Voorburg'],
#  ['Vito', 1485.8453538466451, 4.3, 'Voorburg'],
#  ["Abby's", 852.017140325663, 4.3, 'Voorburg'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Voorburg'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Voorburg'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Voorburg'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Voorburg'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Voorburg'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Voorburg'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Voorburg'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Voorburg'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Voorburg'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Voorburg'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Voorburg'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Voorburg'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Voorburg'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Voorburg'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Voorburg'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Voorburg'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Voorburg'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Voorburg'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Voorburg'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Voorburg'],
#  ['Moeke', 484.4824365505958, 0.0, 'Voorburg'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Voorburg'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Voorburg'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Voorburg'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Voorburg'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Voorburg'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Voorburg'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Voorburg'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Voorburg'],
#  ['Subway', 861.8243738210845, 5.0, 'Voorburg'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Voorburg'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Oss'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Oss'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Oss'],
#  ['Burger King', 38.753209797124605, 3.0, 'Oss'],
#  ['Deli', 1009.748379483375, 4.8, 'Oss'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Oss'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Oss'],
#  ['King Sing', 212.2733144925375, 3.0, 'Oss'],
#  ['Aloha', 852.7449434363177, 4.0, 'Oss'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Oss'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Oss'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Oss'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Oss'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Oss'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Oss'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Oss'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Oss'],
#  ['Vito', 1485.8453538466451, 4.3, 'Oss'],
#  ["Abby's", 852.017140325663, 4.3, 'Oss'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Oss'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Oss'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Oss'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Oss'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Oss'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Oss'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Oss'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Oss'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Oss'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Oss'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Oss'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Oss'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Oss'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Oss'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Oss'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Oss'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Oss'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Oss'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Oss'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Oss'],
#  ['Moeke', 484.4824365505958, 0.0, 'Oss'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Oss'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Oss'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Oss'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Oss'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Oss'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Oss'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Oss'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Oss'],
#  ['Subway', 861.8243738210845, 5.0, 'Oss'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Oss'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Bussum Zuid'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Bussum Zuid'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Bussum Zuid'],
#  ['Burger King', 38.753209797124605, 3.0, 'Bussum Zuid'],
#  ['Deli', 1009.748379483375, 4.8, 'Bussum Zuid'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Bussum Zuid'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Bussum Zuid'],
#  ['King Sing', 212.2733144925375, 3.0, 'Bussum Zuid'],
#  ['Aloha', 852.7449434363177, 4.0, 'Bussum Zuid'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Bussum Zuid'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Bussum Zuid'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Bussum Zuid'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Bussum Zuid'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Bussum Zuid'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Bussum Zuid'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Bussum Zuid'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Bussum Zuid'],
#  ['Vito', 1485.8453538466451, 4.3, 'Bussum Zuid'],
#  ["Abby's", 852.017140325663, 4.3, 'Bussum Zuid'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Bussum Zuid'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Bussum Zuid'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Bussum Zuid'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Bussum Zuid'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Bussum Zuid'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Bussum Zuid'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Bussum Zuid'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Bussum Zuid'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Bussum Zuid'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Bussum Zuid'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Bussum Zuid'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Bussum Zuid'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Bussum Zuid'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Bussum Zuid'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Bussum Zuid'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Bussum Zuid'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Bussum Zuid'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Bussum Zuid'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Bussum Zuid'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Bussum Zuid'],
#  ['Moeke', 484.4824365505958, 0.0, 'Bussum Zuid'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Bussum Zuid'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Bussum Zuid'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Bussum Zuid'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Bussum Zuid'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Bussum Zuid'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Bussum Zuid'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Bussum Zuid'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Bussum Zuid'],
#  ['Subway', 861.8243738210845, 5.0, 'Bussum Zuid'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Bussum Zuid'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Boxmeer'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Boxmeer'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Boxmeer'],
#  ['Burger King', 38.753209797124605, 3.0, 'Boxmeer'],
#  ['Deli', 1009.748379483375, 4.8, 'Boxmeer'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Boxmeer'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Boxmeer'],
#  ['King Sing', 212.2733144925375, 3.0, 'Boxmeer'],
#  ['Aloha', 852.7449434363177, 4.0, 'Boxmeer'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Boxmeer'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Boxmeer'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Boxmeer'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Boxmeer'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Boxmeer'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Boxmeer'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Boxmeer'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Boxmeer'],
#  ['Vito', 1485.8453538466451, 4.3, 'Boxmeer'],
#  ["Abby's", 852.017140325663, 4.3, 'Boxmeer'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Boxmeer'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Boxmeer'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Boxmeer'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Boxmeer'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Boxmeer'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Boxmeer'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Boxmeer'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Boxmeer'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Boxmeer'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Boxmeer'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Boxmeer'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Boxmeer'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Boxmeer'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Boxmeer'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Boxmeer'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Boxmeer'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Boxmeer'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Boxmeer'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Boxmeer'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Boxmeer'],
#  ['Moeke', 484.4824365505958, 0.0, 'Boxmeer'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Boxmeer'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Boxmeer'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Boxmeer'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Boxmeer'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Boxmeer'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Boxmeer'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Boxmeer'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Boxmeer'],
#  ['Subway', 861.8243738210845, 5.0, 'Boxmeer'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Boxmeer'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Didam'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Didam'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Didam'],
#  ['Burger King', 38.753209797124605, 3.0, 'Didam'],
#  ['Deli', 1009.748379483375, 4.8, 'Didam'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Didam'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Didam'],
#  ['King Sing', 212.2733144925375, 3.0, 'Didam'],
#  ['Aloha', 852.7449434363177, 4.0, 'Didam'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Didam'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Didam'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Didam'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Didam'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Didam'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Didam'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Didam'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Didam'],
#  ['Vito', 1485.8453538466451, 4.3, 'Didam'],
#  ["Abby's", 852.017140325663, 4.3, 'Didam'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Didam'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Didam'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Didam'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Didam'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Didam'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Didam'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Didam'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Didam'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Didam'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Didam'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Didam'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Didam'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Didam'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Didam'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Didam'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Didam'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Didam'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Didam'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Didam'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Didam'],
#  ['Moeke', 484.4824365505958, 0.0, 'Didam'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Didam'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Didam'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Didam'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Didam'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Didam'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Didam'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Didam'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Didam'],
#  ['Subway', 861.8243738210845, 5.0, 'Didam'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Didam'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Delfzijl'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Delfzijl'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Delfzijl'],
#  ['Burger King', 38.753209797124605, 3.0, 'Delfzijl'],
#  ['Deli', 1009.748379483375, 4.8, 'Delfzijl'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Delfzijl'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Delfzijl'],
#  ['King Sing', 212.2733144925375, 3.0, 'Delfzijl'],
#  ['Aloha', 852.7449434363177, 4.0, 'Delfzijl'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Delfzijl'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Delfzijl'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Delfzijl'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Delfzijl'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Delfzijl'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Delfzijl'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Delfzijl'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Delfzijl'],
#  ['Vito', 1485.8453538466451, 4.3, 'Delfzijl'],
#  ["Abby's", 852.017140325663, 4.3, 'Delfzijl'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Delfzijl'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Delfzijl'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Delfzijl'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Delfzijl'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Delfzijl'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Delfzijl'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Delfzijl'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Delfzijl'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Delfzijl'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Delfzijl'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Delfzijl'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Delfzijl'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Delfzijl'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Delfzijl'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Delfzijl'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Delfzijl'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Delfzijl'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Delfzijl'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Delfzijl'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Delfzijl'],
#  ['Moeke', 484.4824365505958, 0.0, 'Delfzijl'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Delfzijl'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Delfzijl'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Delfzijl'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Delfzijl'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Delfzijl'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Delfzijl'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Delfzijl'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Delfzijl'],
#  ['Subway', 861.8243738210845, 5.0, 'Delfzijl'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Delfzijl'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Pijnacker Zuid'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Pijnacker Zuid'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Pijnacker Zuid'],
#  ['Burger King', 38.753209797124605, 3.0, 'Pijnacker Zuid'],
#  ['Deli', 1009.748379483375, 4.8, 'Pijnacker Zuid'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Pijnacker Zuid'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Pijnacker Zuid'],
#  ['King Sing', 212.2733144925375, 3.0, 'Pijnacker Zuid'],
#  ['Aloha', 852.7449434363177, 4.0, 'Pijnacker Zuid'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Pijnacker Zuid'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Pijnacker Zuid'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Pijnacker Zuid'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Pijnacker Zuid'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Pijnacker Zuid'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Pijnacker Zuid'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Pijnacker Zuid'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Pijnacker Zuid'],
#  ['Vito', 1485.8453538466451, 4.3, 'Pijnacker Zuid'],
#  ["Abby's", 852.017140325663, 4.3, 'Pijnacker Zuid'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Pijnacker Zuid'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Pijnacker Zuid'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Pijnacker Zuid'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Pijnacker Zuid'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Pijnacker Zuid'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Pijnacker Zuid'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Pijnacker Zuid'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Pijnacker Zuid'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Pijnacker Zuid'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Pijnacker Zuid'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Pijnacker Zuid'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Pijnacker Zuid'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Pijnacker Zuid'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Pijnacker Zuid'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Pijnacker Zuid'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Pijnacker Zuid'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Pijnacker Zuid'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Pijnacker Zuid'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Pijnacker Zuid'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Pijnacker Zuid'],
#  ['Moeke', 484.4824365505958, 0.0, 'Pijnacker Zuid'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Pijnacker Zuid'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Pijnacker Zuid'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Pijnacker Zuid'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Pijnacker Zuid'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Pijnacker Zuid'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Pijnacker Zuid'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Pijnacker Zuid'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Pijnacker Zuid'],
#  ['Subway', 861.8243738210845, 5.0, 'Pijnacker Zuid'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Pijnacker Zuid'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Maassluis'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Maassluis'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Maassluis'],
#  ['Burger King', 38.753209797124605, 3.0, 'Maassluis'],
#  ['Deli', 1009.748379483375, 4.8, 'Maassluis'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Maassluis'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Maassluis'],
#  ['King Sing', 212.2733144925375, 3.0, 'Maassluis'],
#  ['Aloha', 852.7449434363177, 4.0, 'Maassluis'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Maassluis'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Maassluis'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Maassluis'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Maassluis'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Maassluis'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Maassluis'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Maassluis'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Maassluis'],
#  ['Vito', 1485.8453538466451, 4.3, 'Maassluis'],
#  ["Abby's", 852.017140325663, 4.3, 'Maassluis'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Maassluis'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Maassluis'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Maassluis'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Maassluis'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Maassluis'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Maassluis'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Maassluis'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Maassluis'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Maassluis'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Maassluis'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Maassluis'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Maassluis'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Maassluis'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Maassluis'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Maassluis'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Maassluis'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Maassluis'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Maassluis'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Maassluis'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Maassluis'],
#  ['Moeke', 484.4824365505958, 0.0, 'Maassluis'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Maassluis'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Maassluis'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Maassluis'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Maassluis'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Maassluis'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Maassluis'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Maassluis'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Maassluis'],
#  ['Subway', 861.8243738210845, 5.0, 'Maassluis'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Maassluis'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'OV-ebike Driebergen-Zeist'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'OV-ebike Driebergen-Zeist'],
#  ['Daikichi', 54.04131208278735, 4.0, 'OV-ebike Driebergen-Zeist'],
#  ['Burger King', 38.753209797124605, 3.0, 'OV-ebike Driebergen-Zeist'],
#  ['Deli', 1009.748379483375, 4.8, 'OV-ebike Driebergen-Zeist'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'OV-ebike Driebergen-Zeist'],
#  ['De Buren', 1060.7939670377473, 4.1, 'OV-ebike Driebergen-Zeist'],
#  ['King Sing', 212.2733144925375, 3.0, 'OV-ebike Driebergen-Zeist'],
#  ['Aloha', 852.7449434363177, 4.0, 'OV-ebike Driebergen-Zeist'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ['Schots Restaurant Hielander',
#   1008.5839781538273,
#   3.8,
#   'OV-ebike Driebergen-Zeist'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ["Mojo's", 942.0027393749233, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'OV-ebike Driebergen-Zeist'],
#  ['Horecacentrum De Studio',
#   516.498093746401,
#   5.0,
#   'OV-ebike Driebergen-Zeist'],
#  ['Vito', 1485.8453538466451, 4.3, 'OV-ebike Driebergen-Zeist'],
#  ["Abby's", 852.017140325663, 4.3, 'OV-ebike Driebergen-Zeist'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'OV-ebike Driebergen-Zeist'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'OV-ebike Driebergen-Zeist'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'OV-ebike Driebergen-Zeist'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'OV-ebike Driebergen-Zeist'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'OV-ebike Driebergen-Zeist'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'OV-ebike Driebergen-Zeist'],
#  ['Pizzeria Ristorante La Famiglia',
#   499.8180731679537,
#   4.0,
#   'OV-ebike Driebergen-Zeist'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'OV-ebike Driebergen-Zeist'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'OV-ebike Driebergen-Zeist'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ['SuperThai Restaurant ',
#   749.6106910535735,
#   3.3,
#   'OV-ebike Driebergen-Zeist'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'OV-ebike Driebergen-Zeist'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'OV-ebike Driebergen-Zeist'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'OV-ebike Driebergen-Zeist'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'OV-ebike Driebergen-Zeist'],
#  ['Granada Grand Cafe & Restaurant',
#   597.1834813755764,
#   5.0,
#   'OV-ebike Driebergen-Zeist'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'OV-ebike Driebergen-Zeist'],
#  ['Kunchai', 994.5218072237367, 4.5, 'OV-ebike Driebergen-Zeist'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ['Moeke', 484.4824365505958, 0.0, 'OV-ebike Driebergen-Zeist'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'OV-ebike Driebergen-Zeist'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ['Taormina', 1149.6070313784464, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'OV-ebike Driebergen-Zeist'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'OV-ebike Driebergen-Zeist'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'OV-ebike Driebergen-Zeist'],
#  ['Subway', 861.8243738210845, 5.0, 'OV-ebike Driebergen-Zeist'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'OV-ebike Driebergen-Zeist'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Amsterdam Sloterdijk'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Amsterdam Sloterdijk'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Amsterdam Sloterdijk'],
#  ['Burger King', 38.753209797124605, 3.0, 'Amsterdam Sloterdijk'],
#  ['Deli', 1009.748379483375, 4.8, 'Amsterdam Sloterdijk'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Amsterdam Sloterdijk'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Amsterdam Sloterdijk'],
#  ['King Sing', 212.2733144925375, 3.0, 'Amsterdam Sloterdijk'],
#  ['Aloha', 852.7449434363177, 4.0, 'Amsterdam Sloterdijk'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Amsterdam Sloterdijk'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Amsterdam Sloterdijk'],
#  ['Schots Restaurant Hielander',
#   1008.5839781538273,
#   3.8,
#   'Amsterdam Sloterdijk'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Amsterdam Sloterdijk'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Amsterdam Sloterdijk'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Amsterdam Sloterdijk'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Amsterdam Sloterdijk'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Amsterdam Sloterdijk'],
#  ['Vito', 1485.8453538466451, 4.3, 'Amsterdam Sloterdijk'],
#  ["Abby's", 852.017140325663, 4.3, 'Amsterdam Sloterdijk'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Amsterdam Sloterdijk'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Amsterdam Sloterdijk'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Amsterdam Sloterdijk'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Amsterdam Sloterdijk'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Amsterdam Sloterdijk'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Amsterdam Sloterdijk'],
#  ['Pizzeria Ristorante La Famiglia',
#   499.8180731679537,
#   4.0,
#   'Amsterdam Sloterdijk'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Amsterdam Sloterdijk'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Amsterdam Sloterdijk'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Amsterdam Sloterdijk'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Amsterdam Sloterdijk'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Amsterdam Sloterdijk'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Amsterdam Sloterdijk'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Amsterdam Sloterdijk'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Amsterdam Sloterdijk'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Amsterdam Sloterdijk'],
#  ['Granada Grand Cafe & Restaurant',
#   597.1834813755764,
#   5.0,
#   'Amsterdam Sloterdijk'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Amsterdam Sloterdijk'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Amsterdam Sloterdijk'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Amsterdam Sloterdijk'],
#  ['Moeke', 484.4824365505958, 0.0, 'Amsterdam Sloterdijk'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Amsterdam Sloterdijk'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Amsterdam Sloterdijk'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Amsterdam Sloterdijk'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Amsterdam Sloterdijk'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Amsterdam Sloterdijk'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Amsterdam Sloterdijk'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Amsterdam Sloterdijk'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Amsterdam Sloterdijk'],
#  ['Subway', 861.8243738210845, 5.0, 'Amsterdam Sloterdijk'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Amsterdam Sloterdijk'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Dieren'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Dieren'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Dieren'],
#  ['Burger King', 38.753209797124605, 3.0, 'Dieren'],
#  ['Deli', 1009.748379483375, 4.8, 'Dieren'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Dieren'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Dieren'],
#  ['King Sing', 212.2733144925375, 3.0, 'Dieren'],
#  ['Aloha', 852.7449434363177, 4.0, 'Dieren'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Dieren'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Dieren'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Dieren'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Dieren'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Dieren'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Dieren'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Dieren'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Dieren'],
#  ['Vito', 1485.8453538466451, 4.3, 'Dieren'],
#  ["Abby's", 852.017140325663, 4.3, 'Dieren'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Dieren'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Dieren'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Dieren'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Dieren'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Dieren'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Dieren'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Dieren'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Dieren'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Dieren'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Dieren'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Dieren'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Dieren'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Dieren'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Dieren'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Dieren'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Dieren'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Dieren'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Dieren'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Dieren'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Dieren'],
#  ['Moeke', 484.4824365505958, 0.0, 'Dieren'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Dieren'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Dieren'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Dieren'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Dieren'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Dieren'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Dieren'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Dieren'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Dieren'],
#  ['Subway', 861.8243738210845, 5.0, 'Dieren'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Dieren'],
#  ['De Binnenkomer',
#   599.4072940907039,
#   4.7,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Vers Eten & Drinken',
#   77.34336015072499,
#   4.5,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Burger King', 38.753209797124605, 3.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Deli', 1009.748379483375, 4.8, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['King Sing', 212.2733144925375, 3.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Aloha', 852.7449434363177, 4.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Stadsstrand de Kade',
#   620.6513341917654,
#   5.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Alkmaars Koffiehuis',
#   723.9196172713763,
#   5.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Schots Restaurant Hielander',
#   1008.5839781538273,
#   3.8,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Saladebar Oogst',
#   479.2986157354422,
#   5.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ["Irish Pub Gunnery's",
#   1101.3625315377635,
#   5.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Het Grand Cafeetje',
#   935.7281656931732,
#   4.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Horecacentrum De Studio',
#   516.498093746401,
#   5.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Vito', 1485.8453538466451, 4.3, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ["Abby's", 852.017140325663, 4.3, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Proeflokaal Bregje',
#   525.2107427451322,
#   2.3,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['restaurant zegels',
#   744.6440355872974,
#   4.7,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Petershoek Café',
#   90.49918999393957,
#   0.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Pizzeria Ristorante La Famiglia',
#   499.8180731679537,
#   4.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Heeren van Sonoy',
#   811.7969541676354,
#   3.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['La Cubanita Alkmaar',
#   1019.1139257354848,
#   5.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['SuperThai Restaurant ',
#   749.6106910535735,
#   3.3,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Café-Bar Odeon',
#   1117.6786219087742,
#   4.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Grand Café Klunder',
#   491.1964571528282,
#   0.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['1480 Food Bar',
#   1019.4541370951409,
#   4.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Restaurant Tapas &',
#   1057.2459116972116,
#   5.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Granada Grand Cafe & Restaurant',
#   597.1834813755764,
#   5.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Proeflokaal De Boom',
#   942.184391949158,
#   0.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Cafe De Pilaren',
#   1085.9413393183647,
#   5.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Moeke', 484.4824365505958, 0.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['De Amstelhoek',
#   967.9020076874574,
#   4.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Rue de la Plume',
#   789.023446360917,
#   5.0,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Ristobar Italica',
#   1083.0744620729238,
#   2.4,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['De Bonte Bengel',
#   574.7221520255662,
#   2.8,
#   'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Subway', 861.8243738210845, 5.0, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Utrecht Vaartsche Rijn Oosterkade'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Zoetermeer Centrum West'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Zoetermeer Centrum West'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Zoetermeer Centrum West'],
#  ['Burger King', 38.753209797124605, 3.0, 'Zoetermeer Centrum West'],
#  ['Deli', 1009.748379483375, 4.8, 'Zoetermeer Centrum West'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Zoetermeer Centrum West'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Zoetermeer Centrum West'],
#  ['King Sing', 212.2733144925375, 3.0, 'Zoetermeer Centrum West'],
#  ['Aloha', 852.7449434363177, 4.0, 'Zoetermeer Centrum West'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Zoetermeer Centrum West'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Zoetermeer Centrum West'],
#  ['Schots Restaurant Hielander',
#   1008.5839781538273,
#   3.8,
#   'Zoetermeer Centrum West'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Zoetermeer Centrum West'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Zoetermeer Centrum West'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Zoetermeer Centrum West'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Zoetermeer Centrum West'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Zoetermeer Centrum West'],
#  ['Vito', 1485.8453538466451, 4.3, 'Zoetermeer Centrum West'],
#  ["Abby's", 852.017140325663, 4.3, 'Zoetermeer Centrum West'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Zoetermeer Centrum West'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Zoetermeer Centrum West'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Zoetermeer Centrum West'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Zoetermeer Centrum West'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Zoetermeer Centrum West'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Zoetermeer Centrum West'],
#  ['Pizzeria Ristorante La Famiglia',
#   499.8180731679537,
#   4.0,
#   'Zoetermeer Centrum West'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Zoetermeer Centrum West'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Zoetermeer Centrum West'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Zoetermeer Centrum West'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Zoetermeer Centrum West'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Zoetermeer Centrum West'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Zoetermeer Centrum West'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Zoetermeer Centrum West'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Zoetermeer Centrum West'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Zoetermeer Centrum West'],
#  ['Granada Grand Cafe & Restaurant',
#   597.1834813755764,
#   5.0,
#   'Zoetermeer Centrum West'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Zoetermeer Centrum West'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Zoetermeer Centrum West'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Zoetermeer Centrum West'],
#  ['Moeke', 484.4824365505958, 0.0, 'Zoetermeer Centrum West'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Zoetermeer Centrum West'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Zoetermeer Centrum West'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Zoetermeer Centrum West'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Zoetermeer Centrum West'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Zoetermeer Centrum West'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Zoetermeer Centrum West'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Zoetermeer Centrum West'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Zoetermeer Centrum West'],
#  ['Subway', 861.8243738210845, 5.0, 'Zoetermeer Centrum West'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Zoetermeer Centrum West'],
#  ['De Binnenkomer', 599.4072940907039, 4.7, 'Woerden'],
#  ['Vers Eten & Drinken', 77.34336015072499, 4.5, 'Woerden'],
#  ['Daikichi', 54.04131208278735, 4.0, 'Woerden'],
#  ['Burger King', 38.753209797124605, 3.0, 'Woerden'],
#  ['Deli', 1009.748379483375, 4.8, 'Woerden'],
#  ['Anne & Max', 1050.9389047964175, 4.8, 'Woerden'],
#  ['De Buren', 1060.7939670377473, 4.1, 'Woerden'],
#  ['King Sing', 212.2733144925375, 3.0, 'Woerden'],
#  ['Aloha', 852.7449434363177, 4.0, 'Woerden'],
#  ['Stadsstrand de Kade', 620.6513341917654, 5.0, 'Woerden'],
#  ['Alkmaars Koffiehuis', 723.9196172713763, 5.0, 'Woerden'],
#  ['Schots Restaurant Hielander', 1008.5839781538273, 3.8, 'Woerden'],
#  ['Saladebar Oogst', 479.2986157354422, 5.0, 'Woerden'],
#  ["Irish Pub Gunnery's", 1101.3625315377635, 5.0, 'Woerden'],
#  ["Mojo's", 942.0027393749233, 5.0, 'Woerden'],
#  ['Het Grand Cafeetje', 935.7281656931732, 4.0, 'Woerden'],
#  ['Horecacentrum De Studio', 516.498093746401, 5.0, 'Woerden'],
#  ['Vito', 1485.8453538466451, 4.3, 'Woerden'],
#  ["Abby's", 852.017140325663, 4.3, 'Woerden'],
#  ['Proeflokaal Bregje', 525.2107427451322, 2.3, 'Woerden'],
#  ['restaurant zegels', 744.6440355872974, 4.7, 'Woerden'],
#  ['Meat & Co', 1020.6355087576528, 4.3, 'Woerden'],
#  ['Fresh Food', 93.87041630226362, 0.0, 'Woerden'],
#  ['Petershoek Café', 90.49918999393957, 0.0, 'Woerden'],
#  ['Burgers & Zo', 566.070511391871, 3.5, 'Woerden'],
#  ['Pizzeria Ristorante La Famiglia', 499.8180731679537, 4.0, 'Woerden'],
#  ['Heeren van Sonoy', 811.7969541676354, 3.0, 'Woerden'],
#  ['Gulden Vlies', 749.6198242086455, 4.0, 'Woerden'],
#  ['La Cubanita Alkmaar', 1019.1139257354848, 5.0, 'Woerden'],
#  ['SuperThai Restaurant ', 749.6106910535735, 3.3, 'Woerden'],
#  ['Café-Bar Odeon', 1117.6786219087742, 4.0, 'Woerden'],
#  ['Grand Café Klunder', 491.1964571528282, 0.0, 'Woerden'],
#  ['1480 Food Bar', 1019.4541370951409, 4.0, 'Woerden'],
#  ['Restaurant Tapas &', 1057.2459116972116, 5.0, 'Woerden'],
#  ['Happy Italy', 518.4117475871739, 3.3, 'Woerden'],
#  ['Granada Grand Cafe & Restaurant', 597.1834813755764, 5.0, 'Woerden'],
#  ['Proeflokaal De Boom', 942.184391949158, 0.0, 'Woerden'],
#  ['Kunchai', 994.5218072237367, 4.5, 'Woerden'],
#  ['Cafe De Pilaren', 1085.9413393183647, 5.0, 'Woerden'],
#  ['Moeke', 484.4824365505958, 0.0, 'Woerden'],
#  ['De Amstelhoek', 967.9020076874574, 4.0, 'Woerden'],
#  ['Il Colosseo', 738.3859911669595, 5.0, 'Woerden'],
#  ['Rue de la Plume', 789.023446360917, 5.0, 'Woerden'],
#  ["'t Friethuys", 937.8352468571736, 5.0, 'Woerden'],
#  ['Taormina', 1149.6070313784464, 5.0, 'Woerden'],
#  ['Ristobar Italica', 1083.0744620729238, 2.4, 'Woerden'],
#  ['Le Bon', 1008.7088239418918, 4.0, 'Woerden'],
#  ['De Bonte Bengel', 574.7221520255662, 2.8, 'Woerden'],
#  ['Subway', 861.8243738210845, 5.0, 'Woerden'],
#  ['Cafe Bali', 920.3244724023469, 3.7, 'Woerden'],
#  ...]

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
df2 = pd.DataFrame(list, columns=['Name','Distance','Rating','Station Name'])

# %%
df2
# Out:
#                      Name     Distance  rating Station Name
# 0          De Binnenkomer   599.407294     4.7      Alkmaar
# 1     Vers Eten & Drinken    77.343360     4.5      Alkmaar
# 2                Daikichi    54.041312     4.0      Alkmaar
# 3             Burger King    38.753210     3.0      Alkmaar
# 4                    Deli  1009.748379     4.8      Alkmaar
# ...                   ...          ...     ...          ...
# 7495     Ristobar Italica  1083.074462     2.4   Ravenstein
# 7496               Le Bon  1008.708824     4.0   Ravenstein
# 7497      De Bonte Bengel   574.722152     2.8   Ravenstein
# 7498               Subway   861.824374     5.0   Ravenstein
# 7499            Cafe Bali   920.324472     3.7   Ravenstein
#
# [7500 rows x 4 columns]

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# I chose yelp, because it had a rating with the restaurants and foursquare did not, as well as the fact that yelp gave more answers.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
df_sorted = df2.sort_values(by='Rating', ascending=False)

# %%
df_sorted.head(10)
# Out:
#                                  Name     Distance  Rating  \
# 5128              La Cubanita Alkmaar  1019.113926     5.0
# 4478              La Cubanita Alkmaar  1019.113926     5.0
# 1733               Restaurant Tapas &  1057.245912     5.0
# 4491                      Il Colosseo   738.385991     5.0
# 1735  Granada Grand Cafe & Restaurant   597.183481     5.0
# 4488                  Cafe De Pilaren  1085.941339     5.0
# 4485  Granada Grand Cafe & Restaurant   597.183481     5.0
# 1738                  Cafe De Pilaren  1085.941339     5.0
# 4483               Restaurant Tapas &  1057.245912     5.0
# 1741                      Il Colosseo   738.385991     5.0
#
#                                 Station Name
# 5128                                   Hoorn
# 4478                        Utrecht Terwijde
# 1733  Eindhoven Centraal zuidzijde (centrum)
# 4491                        Utrecht Terwijde
# 1735  Eindhoven Centraal zuidzijde (centrum)
# 4488                        Utrecht Terwijde
# 4485                        Utrecht Terwijde
# 1738  Eindhoven Centraal zuidzijde (centrum)
# 4483                        Utrecht Terwijde
# 1741  Eindhoven Centraal zuidzijde (centrum)

# %%
df2.to_csv('yelp_data.csv')
